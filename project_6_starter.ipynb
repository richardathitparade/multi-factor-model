# %% [markdown]
# # Project 6: Analyzing Stock Sentiment from Twits
# ## Instructions
# Each problem consists of a function to implement and instructions on how to implement the function.  The parts of the function that need to be implemented are marked with a `# TODO` comment.
#
# ## Packages
# When you implement the functions, you'll only need to you use the packages you've used in the classroom, like [Pandas](https://pandas.pydata.org/) and [Numpy](http://www.numpy.org/). These packages will be imported for you. We recommend you don't add any import statements, otherwise the grader might not be able to run your code.
#
# ### Load Packages

# %%
import json
import nltk
import os
import random
import re
import torch

from torch import nn, optim
import torch.nn.functional as F

# %% [markdown]
# ## Introduction
# When deciding the value of a company, it's important to follow the news. For example, a product recall or natural disaster in a company's product chain. You want to be able to turn this information into a signal. Currently, the best tool for the job is a Neural Network.
#
# For this project, you'll use posts from the social media site [StockTwits](https://en.wikipedia.org/wiki/StockTwits). The community on StockTwits is full of investors, traders, and entrepreneurs. Each message posted is called a Twit. This is similar to Twitter's version of a post, called a Tweet. You'll build a model around these twits that generate a sentiment score.
#
# We've collected a bunch of twits, then hand labeled the sentiment of each. To capture the degree of sentiment, we'll use a five-point scale: very negative, negative, neutral, positive, very positive. Each twit is labeled -2 to 2 in steps of 1, from very negative to very positive respectively. You'll build a sentiment analysis model that will learn to assign sentiment to twits on its own, using this labeled data.
#
# The first thing we should to do, is load the data.
#
# ## Import Twits
# ### Load Twits Data
# This JSON file contains a list of objects for each twit in the `'data'` field:
#
# ```
# {'data':
#   {'message_body': 'Neutral twit body text here',
#    'sentiment': 0},
#   {'message_body': 'Happy twit body text here',
#    'sentiment': 1},
#    ...
# }
# ```
#
# The fields represent the following:
#
# * `'message_body'`: The text of the twit.
# * `'sentiment'`: Sentiment score for the twit, ranges from -2 to 2 in steps of 1, with 0 being neutral.
#
#
# To see what the data look like by printing the first 10 twits from the list.

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'twits.json'), 'r') as f:
    twits = json.load(f)

print(twits['data'][:10])
# Out:
# [{'message_body': '$FITB great buy at 26.00...ill wait', 'sentiment': 2, 'timestamp': '2018-07-01T00:00:09Z'}, {'message_body': '@StockTwits $MSFT', 'sentiment': 1, 'timestamp': '2018-07-01T00:00:42Z'}, {'message_body': '#STAAnalystAlert for $TDG : Jefferies Maintains with a rating of Hold setting target price at USD 350.00. Our own verdict is Buy  http://www.stocktargetadvisor.com/toprating', 'sentiment': 2, 'timestamp': '2018-07-01T00:01:24Z'}, {'message_body': '$AMD I heard there’s a guy who knows someone who thinks somebody knows something - on StockTwits.', 'sentiment': 1, 'timestamp': '2018-07-01T00:01:47Z'}, {'message_body': '$AMD reveal yourself!', 'sentiment': 0, 'timestamp': '2018-07-01T00:02:13Z'}, {'message_body': '$AAPL Why the drop? I warren Buffet taking out his position?', 'sentiment': 1, 'timestamp': '2018-07-01T00:03:10Z'}, {'message_body': '$BA bears have 1 reason on 06-29 to pay more attention https://dividendbot.com?s=BA', 'sentiment': -2, 'timestamp': '2018-07-01T00:04:09Z'}, {'message_body': '$BAC ok good we&#39;re not dropping in price over the weekend, lol', 'sentiment': 1, 'timestamp': '2018-07-01T00:04:17Z'}, {'message_body': '$AMAT - Daily Chart, we need to get back to above 50.', 'sentiment': 2, 'timestamp': '2018-07-01T00:08:01Z'}, {'message_body': '$GME 3% drop per week after spike... if no news in 3 months, back to 12s... if BO, then bingo... what is the odds?', 'sentiment': -2, 'timestamp': '2018-07-01T00:09:03Z'}]

# %% [markdown]
# ### Length of Data
# Now let's look at the number of twits in dataset. Print the number of twits below.

# %%
"""print out the number of twits"""

# TODO Implement 
print(len(twits['data']))
# Out:
# 1548010

# %% [markdown]
# ### Split Message Body and Sentiment Score

# %%
messages = [twit['message_body'] for twit in twits['data']]
# Since the sentiment scores are discrete, we'll scale the sentiments to 0 to 4 for use in our network
sentiments = [twit['sentiment'] + 2 for twit in twits['data']]

# %% [markdown]
# ## Preprocessing the Data
# With our data in hand we need to preprocess our text. These twits are collected by filtering on ticker symbols where these are denoted with a leader $ symbol in the twit itself. For example,
#
# `{'message_body': 'RT @google Our annual look at the year in Google blogging (and beyond) http://t.co/sptHOAh8 $GOOG',
#  'sentiment': 0}`
#
# The ticker symbols don't provide information on the sentiment, and they are in every twit, so we should remove them. This twit also has the `@google` username, again not providing sentiment information, so we should also remove it. We also see a URL `http://t.co/sptHOAh8`. Let's remove these too.
#
# The easiest way to remove specific words or phrases is with regex using the `re` module. You can sub out specific patterns with a space:
#
# ```python
# re.sub(pattern, ' ', text)
# ```
# This will substitute a space with anywhere the pattern matches in the text. Later when we tokenize the text, we'll split appropriately on those spaces.

# %% [markdown]
# ### Pre-Processing

# %%
nltk.download('wordnet')


def preprocess(message):
    """
    This function takes a string as input, then performs these operations: 
        - lowercase
        - remove URLs
        - remove ticker symbols 
        - removes punctuation
        - tokenize by splitting the string on whitespace 
        - removes any single character tokens
    
    Parameters
    ----------
        message : The text message to be preprocessed.
        
    Returns
    -------
        tokens: The preprocessed text into tokens.
    """ 
    #TODO: Implement 
    
    # Lowercase the twit message
    text = message.lower()
    
    # Replace URLs with a space in the message
    text = re.sub(r'https?:\/\/.*[\r\n]*', ' ', text)
    
    # Replace ticker symbols with a space. The ticker symbols are any stock symbol that starts with $.
    text = re.sub(r'[$][A-Za-z][\S]*',  ' ',text)
    
    # Replace StockTwits usernames with a space. The usernames are any word that starts with @.
    text = re.sub(r'[@][A-Za-z][\S]*', ' ', text)

    # Replace everything not a letter with a space
    text = re.sub(r'[\W_]+', ' ', text)
    
    # Tokenize by splitting the string on whitespace into a list of words
    tokens = text.split()

    # Lemmatize words using the WordNetLemmatizer. You can ignore any word that is not longer than one character.
    wnl = nltk.stem.WordNetLemmatizer() 
    
    return [wnl.lemmatize(token) for token in tokens if len(token) > 1]
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %% [markdown]
# ### Preprocess All the Twits
# Now we can preprocess each of the twits in our dataset. Apply the function `preprocess` to all the twit messages.

# %%
# TODO Implement

tokenized = [preprocess(twit) for twit in messages]
tokenized
# Out:
# [['great', 'buy', 'at', '26', '00', 'ill', 'wait'],
#  [],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   '350',
#   '00',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['heard',
#   'there',
#   'guy',
#   'who',
#   'know',
#   'someone',
#   'who',
#   'think',
#   'somebody',
#   'know',
#   'something',
#   'on',
#   'stocktwits'],
#  ['reveal', 'yourself'],
#  ['why',
#   'the',
#   'drop',
#   'warren',
#   'buffet',
#   'taking',
#   'out',
#   'his',
#   'position'],
#  ['bear',
#   'have',
#   'reason',
#   'on',
#   '06',
#   '29',
#   'to',
#   'pay',
#   'more',
#   'attention'],
#  ['ok',
#   'good',
#   'we',
#   '39',
#   're',
#   'not',
#   'dropping',
#   'in',
#   'price',
#   'over',
#   'the',
#   'weekend',
#   'lol'],
#  ['daily', 'chart', 'we', 'need', 'to', 'get', 'back', 'to', 'above', '50'],
#  ['drop',
#   'per',
#   'week',
#   'after',
#   'spike',
#   'if',
#   'no',
#   'news',
#   'in',
#   'month',
#   'back',
#   'to',
#   '12',
#   'if',
#   'bo',
#   'then',
#   'bingo',
#   'what',
#   'is',
#   'the',
#   'odds'],
#  ['strong', 'buy'],
#  ['short',
#   'ratio',
#   'is',
#   '17',
#   'at',
#   '2018',
#   '06',
#   '15',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   '42'],
#  ['price',
#   'squeezing',
#   'perfect',
#   'place',
#   'for',
#   'an',
#   'option',
#   'straddle',
#   'near',
#   'the',
#   'supporting',
#   'trend'],
#  ['start',
#   'of',
#   'new',
#   'on',
#   'monday',
#   'expect',
#   'strong',
#   'buy',
#   'volume',
#   'across',
#   'key',
#   'company',
#   'of',
#   'various',
#   'sector'],
#  ['breakout', 'strategy', 'current', 'portfolio'],
#  ['bull',
#   'have',
#   'reason',
#   'on',
#   '06',
#   '29',
#   'to',
#   'pay',
#   'more',
#   'attention'],
#  ['catalyst',
#   'continuing',
#   'this',
#   'new',
#   'uptrend',
#   'pill',
#   'pack',
#   'buy',
#   'out',
#   'amazon',
#   'prime',
#   'day',
#   'earnings',
#   'test',
#   'break',
#   'of',
#   '1763',
#   'soon'],
#  ['ha',
#   'moved',
#   '21',
#   'on',
#   '06',
#   '29',
#   'check',
#   'out',
#   'the',
#   'movement',
#   'and',
#   'peer',
#   'at'],
#  ['staanalystalert',
#   'for',
#   'mkm',
#   'partner',
#   'set',
#   'price',
#   'target',
#   'with',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   '91',
#   '00',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['think',
#   'it',
#   'is',
#   'too',
#   'early',
#   'to',
#   'tell',
#   'what',
#   'going',
#   'to',
#   'happen',
#   'monday',
#   'even',
#   'with',
#   'the',
#   'current',
#   'news',
#   'about',
#   'raisinf',
#   'output',
#   'there',
#   'is',
#   'still',
#   'so',
#   'many'],
#  ['ha',
#   'current',
#   'ratio',
#   'of',
#   '66',
#   'so',
#   'it',
#   'is',
#   'financially',
#   'healthy',
#   'and',
#   'ha',
#   'no',
#   'problem',
#   'in',
#   'meeting',
#   'it',
#   'obligation'],
#  ['bullish', 'stock', 'to', 'watch', 'setup', 'timeframes'],
#  ['just', 'short', 'it'],
#  ['high', 'alert', 'for', 'next', 'week', 'gt', '14', '40', 'breakdown'],
#  ['the',
#   'current',
#   'ratio',
#   'of',
#   'is',
#   'much',
#   'better',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of',
#   '71'],
#  ['miss', 'these', 'day'],
#  ['if',
#   '14',
#   '40',
#   'break',
#   'and',
#   'confirms',
#   'next',
#   'week',
#   'you',
#   'will',
#   'see',
#   'violent',
#   'move',
#   'downward',
#   'to',
#   'my',
#   'buy',
#   'price'],
#  ['bear',
#   'have',
#   'reason',
#   'on',
#   '06',
#   '29',
#   'to',
#   'pay',
#   'more',
#   'attention'],
#  ['17',
#   'breakout',
#   'base',
#   'gap',
#   'and',
#   '200',
#   'day',
#   'ma',
#   'gap',
#   'gap',
#   'gap',
#   'and',
#   '200',
#   'day',
#   'ma'],
#  ['cabot',
#   'weekly',
#   'video',
#   'quot',
#   'resilient',
#   'growth',
#   'stock',
#   'to',
#   'watch',
#   'quot'],
#  ['when',
#   'wa',
#   'kid',
#   'my',
#   'froend',
#   'told',
#   'me',
#   'the',
#   'moon',
#   'wa',
#   'made',
#   'out',
#   'of',
#   'cheese'],
#  ['short',
#   'volume',
#   'percent',
#   'for',
#   'wa',
#   '35',
#   '42',
#   'on',
#   '06',
#   '28',
#   '18',
#   'and',
#   '20',
#   'day',
#   'rank',
#   'wa',
#   '20th',
#   'percentile'],
#  ['thank',
#   'you',
#   'don',
#   'feel',
#   'the',
#   'need',
#   'to',
#   'tell',
#   'or',
#   'to',
#   'do',
#   'well',
#   'for',
#   'me',
#   'they',
#   'already',
#   'have'],
#  ['during',
#   'the',
#   'youtube',
#   'interview',
#   'mitch',
#   'couldn',
#   '39',
#   'remember',
#   'single',
#   'movie',
#   'he',
#   'watched',
#   'all',
#   'year',
#   'except',
#   'star',
#   'war',
#   'black',
#   'panther',
#   'clothes'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   '38',
#   '00',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'hold'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '43'],
#  ['ha',
#   'better',
#   'return',
#   'on',
#   'equity',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of',
#   '40',
#   '97'],
#  ['although',
#   'the',
#   'market',
#   'is',
#   'up',
#   'is',
#   'doing',
#   'even',
#   'better',
#   'it',
#   'ha',
#   'advanced',
#   '05',
#   'a',
#   'of',
#   '06',
#   '29',
#   'more',
#   'info',
#   'peer',
#   'at'],
#  ['july',
#   'will',
#   'be',
#   'the',
#   'most',
#   'bullish',
#   'day',
#   'of',
#   'the',
#   'year',
#   'for',
#   'stock'],
#  ['option',
#   'volume',
#   'wa',
#   '5x',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   '154',
#   '810',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   '43',
#   'and',
#   'put',
#   'volume',
#   'wa',
#   '57'],
#  ['third', 'design', 'win', 'the', 'timing', 'match', 'it', 'probably', 'arm'],
#  ['alcohol',
#   'stock',
#   'tobacco',
#   'stock',
#   'and',
#   'firearm',
#   'stock',
#   'to',
#   'buy'],
#  ['president',
#   'trump',
#   'tweet',
#   'just',
#   'spoke',
#   'to',
#   'king',
#   'salman',
#   'of',
#   'saudi',
#   'arabia',
#   'and',
#   'explained',
#   'to',
#   'him',
#   'that',
#   'because',
#   'of',
#   'the',
#   'turmoil',
#   'amp'],
#  ['today', '39', 'insight', 'on'],
#  ['intc',
#   'mama',
#   'said',
#   'get',
#   'ice',
#   'cream',
#   'if',
#   'finish',
#   'my',
#   'due',
#   'dil'],
#  ['just',
#   'noticed',
#   'they',
#   'have',
#   'the',
#   'last',
#   'jedi',
#   'on',
#   'stream',
#   'love',
#   'this',
#   'stock'],
#  ['here', 'you', 'go', 'will', 'just', 'leave', 'this', 'here'],
#  ['good',
#   'view',
#   'daily',
#   'still',
#   'look',
#   'good',
#   '5ema',
#   'held',
#   'above',
#   '20ema',
#   'and',
#   'stochastics',
#   'turning',
#   'healthy',
#   'a',
#   'spy',
#   'qqq',
#   'opposite'],
#  ['with',
#   'forward',
#   'pe',
#   'of',
#   '75',
#   'the',
#   'valuation',
#   'of',
#   'can',
#   'be',
#   'described',
#   'a',
#   'cheap'],
#  ['saber',
#   'capital',
#   '39',
#   'presentation',
#   'common',
#   'denominator',
#   'of',
#   'tencent',
#   'facebook',
#   'and',
#   'google'],
#  ['how', 'expect', 'the', 'earnings'],
#  ['is',
#   'one',
#   'of',
#   'the',
#   'better',
#   'performing',
#   'stock',
#   'in',
#   'the',
#   'crude',
#   'petroleum',
#   'and',
#   'natural',
#   'gas',
#   'industry'],
#  ['pu',
#   'it',
#   'simply',
#   'havent',
#   'lost',
#   'on',
#   'any',
#   'brown',
#   'guy',
#   'run',
#   'tech',
#   'company',
#   'mf',
#   'are',
#   'well',
#   'educated',
#   'know',
#   'their',
#   'shit',
#   'more',
#   'more',
#   'every',
#   'year'],
#  ['former',
#   'president',
#   'of',
#   'global',
#   'manufacturing',
#   'at',
#   'pfizer',
#   'is',
#   'an',
#   'independent',
#   'director',
#   'at',
#   'nat',
#   'ricciardi'],
#  ['may', 'be', 'the', 'safest', 'stock', 'own'],
#  ['special',
#   'limited',
#   'offer',
#   'june',
#   '14th',
#   'june',
#   '30th',
#   'tradenet',
#   'is',
#   'offering',
#   '20',
#   'discount',
#   'on',
#   'intro',
#   'program'],
#  ['below', '26', '30', 'buy', 'put', 'on', 'financials'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   '39',
#   '2018',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'stock'],
#  ['low',
#   'peg',
#   'ratio',
#   'which',
#   'compensates',
#   'the',
#   'pe',
#   'for',
#   'growth',
#   'indicates',
#   'rather',
#   'cheap',
#   'valuation'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   '39',
#   '2018',
#   'sohn',
#   'pres',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'equity'],
#  ['35', 'coming'],
#  ['seems',
#   'is',
#   'the',
#   'support',
#   'next',
#   '25',
#   'if',
#   'under',
#   '25',
#   '75',
#   'is',
#   'likely'],
#  ['ha',
#   'moved',
#   '53',
#   'on',
#   '06',
#   '29',
#   'check',
#   'out',
#   'the',
#   'movement',
#   'and',
#   'peer',
#   'at'],
#  ['bullshit',
#   'worthless',
#   'mean',
#   'fucking',
#   'nothing',
#   'this',
#   'is',
#   'macau',
#   'not',
#   'fucking',
#   'usa'],
#  ['take',
#   'this',
#   'let',
#   'me',
#   'know',
#   'where',
#   'are',
#   'we',
#   'right',
#   'now',
#   'lol'],
#  ['the',
#   'chart',
#   'look',
#   'so',
#   'ugly',
#   'without',
#   'clear',
#   'support',
#   'level',
#   'short',
#   'term',
#   'bearish',
#   '39',
#   'll',
#   'buy',
#   'when',
#   'this',
#   'is',
#   'at',
#   '42'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   '39',
#   '39',
#   '18',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'stock'],
#  ['previously',
#   'there',
#   'wa',
#   'mo',
#   'run',
#   'up',
#   'followed',
#   'by',
#   '20',
#   'drop',
#   'we',
#   'are',
#   'at',
#   'the',
#   'end',
#   'of',
#   'month',
#   'of',
#   'another',
#   'runup',
#   'and',
#   'have',
#   'dropped',
#   'about',
#   '10'],
#  ['smart', 'money', 'betting', 'on', 'call', 'deal', 'update'],
#  ['although',
#   'the',
#   'technical',
#   'rating',
#   'is',
#   'bad',
#   'doe',
#   'present',
#   'nice',
#   'setup',
#   'opportunity'],
#  ['will',
#   'completely',
#   'scale',
#   'out',
#   'in',
#   'time',
#   'to',
#   'gobble',
#   'up',
#   'my',
#   'next',
#   'long',
#   'play',
#   'aka',
#   'my',
#   'favorite',
#   'gt'],
#  ['2018',
#   '06',
#   '28',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'is',
#   '35'],
#  ['them', 'are', 'iddy', 'bitty', 'kiddy', 'hand'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   '77',
#   'at',
#   '2018',
#   '06',
#   '15',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   '12',
#   '75'],
#  ['then',
#   'awesome',
#   'it',
#   'is',
#   '43',
#   'now',
#   '39',
#   'be',
#   'concerned',
#   'if',
#   'not',
#   'over',
#   'by',
#   'eow',
#   'might',
#   'get',
#   'under',
#   'next',
#   'wk',
#   'or',
#   'soon'],
#  ['throwback'],
#  ['staanalystalert',
#   'for',
#   'u',
#   'capital',
#   'advisor',
#   'upgrade',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['lol',
#   'all',
#   'these',
#   'shorties',
#   'are',
#   'dreaming',
#   'of',
#   'great',
#   'depression',
#   'or',
#   'somethin',
#   'loll'],
#  ['just',
#   'updated',
#   'hormel',
#   'food',
#   'dividend',
#   'king',
#   'stock',
#   'analysis',
#   'dividend',
#   'king',
#   'consumer',
#   'defensive'],
#  ['today', '39', 'insight', 'on'],
#  ['just',
#   'updated',
#   'intel',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology'],
#  ['today', '39', 'insight', 'on'],
#  ['the',
#   'long',
#   'and',
#   'short',
#   'term',
#   'trend',
#   'are',
#   'both',
#   'positive',
#   'this',
#   'is',
#   'looking',
#   'good'],
#  ['they', 'so', 'mad', 'at', 'me', 'still'],
#  ['back', 'to', '38', 'by', 'july', '20'],
#  ['report', 'and', 'block', 'this', 'person', 'spam'],
#  ['should', 'open', 'at', '400', 'on', 'monday'],
#  ['my',
#   'projection',
#   'for',
#   'if',
#   'thats',
#   'true',
#   'under',
#   'is',
#   'next',
#   'week',
#   'thats',
#   'why',
#   '39',
#   'prefer',
#   'to',
#   'buy',
#   'from',
#   'support',
#   'level'],
#  ['what', 'turd'],
#  ['percent',
#   'short',
#   'volume',
#   'for',
#   'wa',
#   '43',
#   '89',
#   'on',
#   '06',
#   '28',
#   '18'],
#  ['wal',
#   'mart',
#   'dividend',
#   'aristocrat',
#   'dividend',
#   'aristocrat',
#   'consumer',
#   'defensive',
#   'valueinvesting',
#   'dvb',
#   'aaamp'],
#  ['looking',
#   'for',
#   'marriage',
#   'have',
#   '2m',
#   'in',
#   'my',
#   'bank',
#   'account',
#   'with',
#   'in',
#   'stock',
#   'dm'],
#  ['short',
#   'ratio',
#   'is',
#   '60',
#   'at',
#   '2018',
#   '06',
#   '15',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   '52'],
#  ['to',
#   'that',
#   'bear',
#   'that',
#   'won',
#   '39',
#   'stop',
#   'posting',
#   'holding',
#   'big',
#   'short',
#   'position',
#   'over',
#   'weekend',
#   'calm',
#   'down',
#   'and',
#   'good',
#   'luck',
#   'lol'],
#  ['the',
#   'chase',
#   'continues',
#   'hopefully',
#   'they',
#   'catch',
#   'him',
#   'before',
#   'lisa',
#   'announces',
#   'the',
#   '3rd',
#   'win'],
#  ['the',
#   'price',
#   'earnings',
#   'ratio',
#   'is',
#   '39',
#   'which',
#   'indicates',
#   'rather',
#   'cheap',
#   'valuation',
#   'of'],
#  ['permamently',
#   'turned',
#   'me',
#   'off',
#   'of',
#   'option',
#   'trading',
#   'and',
#   'maybe',
#   'stock',
#   'altogether',
#   'manipulation',
#   'by',
#   'very',
#   'rich',
#   'to',
#   'make',
#   'me',
#   'very',
#   'poor',
#   'fuk',
#   'it'],
#  ['is',
#   'down',
#   'almost',
#   '15',
#   'pct',
#   'from',
#   'it',
#   '52',
#   'week',
#   'high',
#   'it',
#   'about',
#   'time',
#   'for',
#   'buyback',
#   'got',
#   '4993',
#   'more',
#   'share',
#   'in',
#   'my',
#   'account',
#   'though',
#   'from',
#   'drip'],
#  ['option',
#   'volume',
#   'wa',
#   '5x',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   '11',
#   '017',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   '81',
#   'and',
#   'put',
#   'volume',
#   'wa',
#   '19'],
#  [],
#  ['dumped',
#   'call',
#   'friday',
#   'at',
#   'open',
#   'that',
#   'wa',
#   'obv',
#   'but',
#   'jeez',
#   'bit',
#   'over',
#   'done',
#   'here'],
#  ['bounce',
#   'off',
#   'support',
#   'heikin',
#   'ashi',
#   'weekly',
#   'candle',
#   'look',
#   'good',
#   'a',
#   'well',
#   'will',
#   'be',
#   'looking',
#   'for',
#   'confirmation'],
#  ['liking', 'this'],
#  ['look',
#   'for',
#   'wife',
#   'got',
#   'about',
#   'tree',
#   'fiddy',
#   'in',
#   'stock',
#   'and',
#   'it',
#   'sure',
#   'my',
#   'piggy',
#   'bank',
#   'ha',
#   'got',
#   'lot',
#   'of',
#   'coin',
#   'may',
#   'spend',
#   'on',
#   'candy',
#   'no',
#   'dm',
#   'though'],
#  ['short',
#   'interest',
#   'ratio',
#   'is',
#   '23',
#   'on',
#   '2018',
#   '06',
#   '15',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   '76'],
#  ['just',
#   'updated',
#   'microsoft',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology'],
#  ['bearish',
#   'investor',
#   'aren',
#   '39',
#   'happy',
#   'today',
#   'for',
#   'a',
#   'of',
#   '06',
#   '29'],
#  ['staanalystalert',
#   'for',
#   'royal',
#   'bank',
#   'of',
#   'canada',
#   'reiterates',
#   'with',
#   'rating',
#   'of',
#   'outperform',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['staanalystalert',
#   'for',
#   'loop',
#   'capital',
#   'raise',
#   'target',
#   'with',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   '80',
#   '00',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['kid', 'never', 'been', 'wrong', 'he', 'miracle'],
#  ['what', 'is', '8o', 'period', 'bollinger', 'band', 'mean'],
#  ['you',
#   'dare',
#   'say',
#   'didn',
#   'know',
#   'you',
#   'are',
#   'a',
#   'guilty',
#   'a',
#   'fudge'],
#  ['today', '39', 'insight', 'on'],
#  ['hardly',
#   'ever',
#   'an',
#   'informative',
#   'comment',
#   'here',
#   'and',
#   'the',
#   'page',
#   'is',
#   'broken',
#   'giving',
#   'endless',
#   'buffering',
#   'icon',
#   'give',
#   'up',
#   'stocktwits'],
#  ['viral',
#   'walk',
#   'away',
#   'video',
#   'highlight',
#   'growing',
#   'movement',
#   'of',
#   'democrat',
#   'leaving',
#   'the',
#   'party',
#   'the',
#   'epoch',
#   'time'],
#  ['staanalystalert',
#   'for',
#   'robert',
#   'baird',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'neutral',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   '80',
#   '00',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['too', 'much', 'weed', 'and', 'other', 'drug', 'guess'],
#  ['with',
#   'forward',
#   'pe',
#   'of',
#   '23',
#   'the',
#   'valuation',
#   'of',
#   'can',
#   'be',
#   'described',
#   'a',
#   'very',
#   'reasonable'],
#  ['the',
#   'reason',
#   'nike',
#   'is',
#   'winning',
#   'is',
#   'because',
#   'of',
#   'their',
#   'click',
#   'booking',
#   'app',
#   'it',
#   'better',
#   'than',
#   'native',
#   'seamless',
#   'lovalized',
#   'transactable',
#   'ap'],
#  ['vitiello', 'tapped', 'a', 'acting', 'ice', 'director', 'via'],
#  ['will',
#   'reach',
#   'over',
#   '100',
#   'this',
#   'year',
#   'iconic',
#   'brand',
#   'global',
#   'technology',
#   'and',
#   'built',
#   'for',
#   'mobile',
#   'winning',
#   'strategy',
#   'amp',
#   'show',
#   'in',
#   'earnings'],
#  ['13', '74', 'by', 'monday', 'morning'],
#  ['this', 'is', 'heading', 'to', 'ath', 'soon', 'maybe', 'next', 'week'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   '65',
#   '00',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['staanalystalert',
#   'for',
#   'baird',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'neutral',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['there',
#   'have',
#   'been',
#   'acquisition',
#   'for',
#   'total',
#   'of',
#   '500',
#   'share',
#   'over',
#   'the',
#   'past',
#   'week',
#   'for'],
#  ['happy', 'trading', 'guy', 'looking', 'to', 'exit', 'today'],
#  ['buy', 'zone'],
#  [],
#  ['fantastic',
#   'read',
#   'oil',
#   'market',
#   'continues',
#   'to',
#   'tighten',
#   '100',
#   'bbl',
#   'is',
#   'getting',
#   'closer'],
#  ['one', 'of', 'the', 'greatest', 'buy'],
#  ['looking',
#   'at',
#   'the',
#   'yearly',
#   'performance',
#   'did',
#   'better',
#   'than',
#   '98',
#   'of',
#   'all',
#   'other',
#   'stock'],
#  ['at',
#   'amp',
#   'dividend',
#   'aristocrat',
#   'dividend',
#   'aristocrat',
#   'champion',
#   'cashflow',
#   'highyield',
#   'telecommunication',
#   'dividend'],
#  ['that',
#   'pretty',
#   'risky',
#   'gamble',
#   'no',
#   'the',
#   'stock',
#   'can',
#   'either',
#   'plummet',
#   'or',
#   'rally'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '35'],
#  ['stronger'],
#  ['apple',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology',
#   'dividend'],
#  ['not', 'talking', 'about', 'wa', 'referring', 'to', 'intelsat'],
#  ['will',
#   'punish',
#   'seller',
#   'who',
#   'don',
#   '39',
#   'move',
#   'stock',
#   'from',
#   'it',
#   'warehouse',
#   'common',
#   'sense',
#   'old',
#   'gather',
#   'dust',
#   'new',
#   'gather',
#   'money'],
#  ['pc',
#   'gamers',
#   'crypto',
#   'miner',
#   'and',
#   'other',
#   'gpu',
#   'enthusiast',
#   'have',
#   'been',
#   'waiting',
#   'over',
#   'two',
#   'year',
#   'for',
#   'the',
#   'company',
#   '39',
#   'next',
#   'big'],
#  ['ha',
#   'only',
#   'medium',
#   'technical',
#   'rating',
#   'but',
#   'it',
#   'doe',
#   'show',
#   'decent',
#   'setup',
#   'pattern'],
#  ['today', '39', 'insight', 'on'],
#  ['what', 'will', 'be', 'more', 'in', 'five', 'year', 'baba', 'or', 'apple'],
#  ['190', 'next', 'week', 'ahhhhhhhhhhhhhhhhhhhhh'],
#  ['2018',
#   '06',
#   '28',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'is',
#   '40'],
#  ['raytheon',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'industrials',
#   'military'],
#  ['why', 'we', 'trending'],
#  ['we',
#   'will',
#   'get',
#   'riiiiiiiiiich',
#   'sooooon',
#   'buuuuls',
#   'looooove',
#   'you',
#   'all',
#   'and',
#   'fucking',
#   'drunk'],
#  ['if',
#   'this',
#   'doesn',
#   'get',
#   'through',
#   '32',
#   '50',
#   'it',
#   'going',
#   'to',
#   'make',
#   'new',
#   'low',
#   'when',
#   'it',
#   'pay',
#   'the',
#   'dividend'],
#  ['gapping', 'up', 'monday'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   '43',
#   'at',
#   '2018',
#   '06',
#   '15',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   '54'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   '64',
#   '00',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['should',
#   'by',
#   'warbey',
#   'parker',
#   'for',
#   '8b',
#   'in',
#   'prep',
#   'for',
#   'apple',
#   'glass',
#   'a',
#   'seen',
#   'with',
#   'watch',
#   'apple',
#   'focus',
#   'on',
#   'fashion',
#   'and',
#   'tech',
#   'wrt',
#   'wearable'],
#  ['look',
#   'like',
#   'sbux',
#   'is',
#   'paying',
#   'full',
#   'sex',
#   'change',
#   'for',
#   'employee',
#   'now',
#   'that',
#   '39',
#   'll',
#   'hit',
#   'the',
#   'bottom',
#   'line'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   '63',
#   'since',
#   'post',
#   'expect',
#   'run',
#   'up',
#   'to',
#   '62',
#   'other',
#   'trade',
#   'included',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam'],
#  ['38',
#   '8b',
#   'enterprise',
#   'value',
#   'v',
#   '17',
#   '8b',
#   'market',
#   'cap',
#   '21b',
#   'difference',
#   'of',
#   'actual',
#   'asset',
#   'v',
#   'market',
#   'value',
#   'too',
#   'big',
#   'spread',
#   'way',
#   'undervalued'],
#  ['50', 'million', 'share', 'added', 'on', 'june', '20', 'dont', 'wait'],
#  ['who',
#   'think',
#   'amazon',
#   'will',
#   'become',
#   'such',
#   'monopoly',
#   'dipping',
#   'into',
#   'everything',
#   'that',
#   'an',
#   'amazon',
#   'airline',
#   'is',
#   'possibility',
#   'do'],
#  ['don',
#   '39',
#   'miss',
#   'the',
#   'breakout',
#   'on',
#   'buy',
#   'stop',
#   '17',
#   '35',
#   'stop',
#   'loss',
#   '14',
#   '95',
#   'is',
#   'suggested',
#   'by',
#   'the',
#   'chartmill',
#   'analyzer'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '50'],
#  ['weekly',
#   'recap',
#   'price',
#   'ha',
#   'moved',
#   '05',
#   'since',
#   'post',
#   'support',
#   '89',
#   'resistance',
#   '95',
#   'other',
#   'trade',
#   'included',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len'],
#  ['weekly',
#   'recap',
#   'price',
#   'ha',
#   'moved',
#   '08',
#   'since',
#   'post',
#   'reversal',
#   'in',
#   'progress',
#   'other',
#   'trade',
#   'included',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy'],
#  ['ve',
#   'recently',
#   'closed',
#   'my',
#   'position',
#   'in',
#   'for',
#   'now',
#   'is',
#   'probably',
#   'next',
#   'on',
#   'the',
#   'list',
#   'bought',
#   'both',
#   'in',
#   'the',
#   'same',
#   'week'],
#  ['nat',
#   'ricciardi',
#   'is',
#   'director',
#   'used',
#   'to',
#   'be',
#   'president',
#   'of',
#   'global',
#   'manufacturing'],
#  ['according',
#   'to',
#   'data',
#   'reported',
#   'to',
#   'finra',
#   'short',
#   'volume',
#   'percent',
#   'for',
#   'clocked',
#   'in',
#   'at',
#   '58',
#   '38',
#   'on',
#   '06',
#   '28',
#   '18'],
#  ['saudi',
#   'official',
#   'came',
#   'out',
#   'saying',
#   'they',
#   'didn',
#   'agree',
#   'to',
#   'this'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   '58',
#   'since',
#   'post',
#   'uptrend',
#   'to',
#   'resume',
#   'other',
#   'trade',
#   'included',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc'],
#  ['the',
#   'one',
#   'on',
#   'the',
#   'right',
#   'cover',
#   'the',
#   'penis',
#   'or',
#   'the',
#   'putang',
#   'the',
#   'front',
#   'leg',
#   'would',
#   'be',
#   'arm'],
#  [],
#  ['some', 'of', 'the', 'stock', 'am', 'watching', 'now'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   '14',
#   '78',
#   'at',
#   '2018',
#   '06',
#   '15',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   '13',
#   '89'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   '99',
#   'since',
#   'post',
#   'next',
#   'stop',
#   '71',
#   'other',
#   'trade',
#   'included',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri'],
#  ['wonder',
#   'how',
#   'much',
#   'this',
#   'will',
#   'be',
#   'valued',
#   'at',
#   'in',
#   '10',
#   'year',
#   'we',
#   'are',
#   'not',
#   'even',
#   'in',
#   'the',
#   '6th',
#   'inning'],
#  ['ha',
#   'bad',
#   'technical',
#   'rating',
#   'but',
#   'it',
#   'doe',
#   'show',
#   'decent',
#   'setup',
#   'pattern'],
#  ['is',
#   'going',
#   'to',
#   'make',
#   'big',
#   'move',
#   'higher',
#   'also',
#   'watching',
#   'apple',
#   'think',
#   'they',
#   'shorted',
#   'the',
#   '165',
#   '175',
#   'put',
#   'spread',
#   'for',
#   'july',
#   '20'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   '91',
#   'since',
#   'post',
#   'expect',
#   'consolidation',
#   'other',
#   'trade',
#   'included',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx'],
#  ['it',
#   '39',
#   'good',
#   'that',
#   'even',
#   'bull',
#   'are',
#   'cautious',
#   'stunned',
#   'bearish',
#   'deeply',
#   'disappointed',
#   'too',
#   'bad',
#   'continues',
#   'it',
#   '39',
#   'old',
#   'way',
#   'hopefully',
#   'we',
#   'are',
#   'close'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   '11',
#   'since',
#   'post',
#   'support',
#   '69',
#   '50',
#   'other',
#   'trade',
#   'included',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn'],
#  ['ending',
#   'june',
#   '32',
#   '430',
#   'killed',
#   'it',
#   'best',
#   'month',
#   'since',
#   'february',
#   '43',
#   '782'],
#  ['funny',
#   'how',
#   'long',
#   'the',
#   'same',
#   'thing',
#   'ha',
#   'been',
#   'going',
#   'on',
#   'with',
#   'this',
#   'about',
#   'year',
#   'of',
#   'this',
#   'similar',
#   'story',
#   'different',
#   'day'],
#  ['bearish',
#   'crab',
#   'well',
#   'measured',
#   'bearish',
#   'crab',
#   'with',
#   'bearish',
#   'divergence',
#   'you',
#   'can',
#   'really',
#   'see',
#   'the',
#   'momentum',
#   'starting',
#   'to',
#   'shi'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   '229',
#   '00',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['google', 'venture', 'company'],
#  ['tariff',
#   'increase',
#   'profit',
#   'how',
#   'can',
#   'it',
#   'be',
#   'bad',
#   'recession',
#   'if',
#   'it',
#   'come',
#   'is',
#   'year',
#   'down',
#   'the',
#   'line',
#   'keep',
#   'buying',
#   'short',
#   'pure',
#   'bull'],
#  ['beanscreen', 'for', 'q3', '2018'],
#  ['the',
#   '15',
#   'min',
#   'chart',
#   'from',
#   'friday',
#   'indicating',
#   'some',
#   'nice',
#   'accumulation',
#   'at',
#   'eod',
#   'could',
#   'be',
#   'nice',
#   'pop',
#   'monday'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'at',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '54'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   '64',
#   'since',
#   'post',
#   'heavy',
#   'resistance',
#   'at',
#   '244',
#   'other',
#   'trade',
#   'included',
#   'apog',
#   'acn',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goo'],
#  ['can', 'we', 'squeeze', 'the', 'short'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   '52',
#   'since',
#   'post',
#   'pullback',
#   'to',
#   '163',
#   'before',
#   'more',
#   'upside',
#   'other',
#   'trade',
#   'included',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goo',
#   'nvda',
#   'apog'],
#  ['still', 'holding', 'call', 'for', 'next', 'week'],
#  ['is',
#   'safe',
#   'but',
#   'their',
#   'buyback',
#   'yield',
#   'is',
#   '10',
#   'div',
#   'yield',
#   '06',
#   '12',
#   '68'],
#  ['adding',
#   'at',
#   '51',
#   '19',
#   'gladly',
#   'let',
#   'irrationality',
#   'reign',
#   'a',
#   'long',
#   'a',
#   'possible',
#   'excess',
#   'gain',
#   'are',
#   'welcome',
#   'gl'],
#  ['looking',
#   'at',
#   'friday',
#   'data',
#   'seeing',
#   'different',
#   'story',
#   'on',
#   'the',
#   'chart',
#   'take',
#   'look',
#   'and',
#   'tell',
#   'me',
#   'what',
#   'you',
#   'think'],
#  ['the',
#   'short',
#   'probably',
#   'aren',
#   '39',
#   'jumping',
#   'for',
#   'joy',
#   'today',
#   'in',
#   'at',
#   'least',
#   'for',
#   '06',
#   '29',
#   'given',
#   'the',
#   'price',
#   'action'],
#  ['bouncing',
#   'off',
#   'support',
#   'need',
#   'continuation',
#   'next',
#   'week',
#   'make',
#   'me',
#   'feel',
#   'more',
#   'hopeful',
#   'for'],
#  ['data',
#   'science',
#   'officially',
#   'became',
#   'major',
#   'in',
#   'university',
#   'this',
#   'year',
#   'to',
#   'support',
#   'ai',
#   'industry',
#   'these',
#   'are',
#   'no',
#   'brainers',
#   'in',
#   'the',
#   'data',
#   'era'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   '62',
#   'at',
#   '2018',
#   '06',
#   '15',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   '71'],
#  [],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   '90',
#   'since',
#   'post',
#   'support',
#   'at',
#   '41',
#   '75',
#   'other',
#   'trade',
#   'included',
#   'payx',
#   'fdx',
#   'goo',
#   'nvda',
#   'apog',
#   'acn',
#   'camp'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '35'],
#  [],
#  ['ha',
#   'better',
#   'return',
#   'on',
#   'equity',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of',
#   '10',
#   '54'],
#  ['53', 'second', 'not', 'minute'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   '12',
#   '12',
#   'since',
#   'post',
#   '80',
#   '100',
#   '120',
#   'rule',
#   'applies',
#   'here',
#   'other',
#   'trade',
#   'included',
#   'zbra',
#   'six',
#   'fc',
#   'gbx',
#   'fds',
#   'avav',
#   'baba'],
#  ['trump',
#   'is',
#   'killing',
#   'the',
#   'tax',
#   'cut',
#   'with',
#   'oil',
#   'price',
#   'and',
#   'tariff',
#   'no',
#   'idea',
#   'what',
#   'he',
#   'doing',
#   'right',
#   'now'],
#  ['haven',
#   '39',
#   'posted',
#   'on',
#   'stocktwits',
#   'in',
#   'while',
#   'these',
#   'weekly',
#   'chart',
#   'look',
#   'good'],
#  ['today', '39', 'insight', 'on'],
#  ['omg', 'toy', 'story', 'land', 'look', 'amazing'],
#  ['10',
#   'stock',
#   'have',
#   'contributed',
#   '100',
#   'of',
#   'ytd',
#   'return',
#   'what',
#   'do',
#   'you',
#   'own'],
#  ['today', '39', 'insight', 'on'],
#  ['my', '3rd', 'most', 'popular', 'word'],
#  ['trump',
#   'tweet',
#   'and',
#   'then',
#   'he',
#   'may',
#   'be',
#   'buyin',
#   'those',
#   'dip',
#   'haha',
#   'still',
#   'makin',
#   'it',
#   'rain',
#   'up',
#   'in',
#   'the',
#   'white',
#   'house'],
#  ['ha',
#   'poor',
#   'technical',
#   'rating',
#   'and',
#   'the',
#   'quality',
#   'of',
#   'the',
#   'setup',
#   'is',
#   'also',
#   'not',
#   'perfect',
#   'at',
#   'the',
#   'moment'],
#  ['doubt',
#   'it',
#   'go',
#   'down',
#   'monday',
#   'and',
#   'doubt',
#   'saudi',
#   'arabia',
#   'increase',
#   'production'],
#  ['measured',
#   'over',
#   'the',
#   'past',
#   'year',
#   'show',
#   'very',
#   'strong',
#   'growth',
#   'in',
#   'eps'],
#  ['constellation', 'brand'],
#  ['the',
#   'short',
#   'probably',
#   'aren',
#   '39',
#   'jumping',
#   'for',
#   'joy',
#   'today',
#   'in',
#   'at',
#   'least',
#   'for',
#   '06',
#   '29',
#   'given',
#   'the',
#   'price',
#   'action'],
#  ['here'],
#  ['did', 'disney', 'just', 'clinch', 'the', 'deal', 'to', 'acquire', 'fox'],
#  ['new', 'way', 'match', 'group', 'can', 'counter', 'facebook'],
#  ['aggregate',
#   'short',
#   'volume',
#   'reported',
#   'to',
#   'finra',
#   'for',
#   'wa',
#   '316',
#   '643',
#   'on',
#   '06',
#   '28',
#   '18'],
#  ['southwest',
#   'airline',
#   'is',
#   'adding',
#   'flight',
#   'in',
#   'dallas',
#   'a',
#   'delta',
#   'spat',
#   'continues'],
#  ['what', 'california'],
#  ['better', 'buy', 'netflix', 'inc', 'nflx', 'versus', 'facebook', 'fb'],
#  ['one', 'thing', 'that', 'starbucks', 'is', 'doing', 'wrong'],
#  [],
#  ['using',
#   'iex',
#   'data',
#   'we',
#   'calculate',
#   'that',
#   'shorters',
#   'have',
#   'lost',
#   '463',
#   '037',
#   'in',
#   'on',
#   '06',
#   '29'],
#  ['bull',
#   'list',
#   'after',
#   'their',
#   'emergence',
#   'from',
#   'bankruptcy',
#   'emergency'],
#  ['zwj',
#   'investment',
#   'counsel',
#   'inc',
#   'lower',
#   'stake',
#   'in',
#   'unitedhealth',
#   'group',
#   'inc',
#   'unh'],
#  ['list', 'of', 'tyzen', 'and', 'vega', 'laptop', 'a', 'of', 'june', '30th'],
#  ['investing',
#   'in',
#   'the',
#   'company',
#   'like',
#   'an',
#   'annuity',
#   'or',
#   '10yr',
#   'bond',
#   'continue',
#   'to',
#   'add',
#   'share',
#   'unsure',
#   'if',
#   'the',
#   'country',
#   'is',
#   'growing',
#   'amd',
#   'is'],
#  ['list',
#   'of',
#   'ryzen',
#   'and',
#   'vega',
#   'laptop',
#   'a',
#   'of',
#   '06',
#   '30',
#   '2018'],
#  ['gettin', 'blasted'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   '72',
#   'since',
#   'post',
#   'strong',
#   'support',
#   'at',
#   'current',
#   'price',
#   'other',
#   'trade',
#   'included',
#   'cgnx',
#   'cx',
#   'aaoi',
#   'aa',
#   'amswa',
#   'yy',
#   'snx'],
#  ['bearish',
#   'shark',
#   'bearish',
#   'shark',
#   'with',
#   'bearish',
#   'divergence',
#   'am',
#   'definitely',
#   'jumping',
#   'into',
#   'the',
#   'august',
#   'put',
#   'on',
#   'monday'],
#  ['so',
#   'is',
#   'g',
#   'going',
#   'to',
#   'give',
#   'u',
#   'price',
#   'point',
#   'before',
#   'or',
#   'after',
#   'earnings'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '55'],
#  ['huge', 'volume', 'at', 'closing', 'on', 'friday'],
#  ['looking', 'for', '114', '115', 'scalp'],
#  ['this',
#   'is',
#   'one',
#   'giant',
#   'fermenting',
#   'turd',
#   'of',
#   'stock',
#   'when',
#   'will',
#   'it',
#   'go',
#   'back',
#   'up',
#   'to',
#   '20',
#   '39'],
#  ['buffet', 'and', 'are', 'buying', 'at', '53', 'per', 'share'],
#  ['in', 'put', 'from', 'last', 'week', 'target', 'zone', 'marked'],
#  ['option',
#   'volume',
#   'wa',
#   '4x',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   '810',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   '19',
#   'and',
#   'put',
#   'volume',
#   'wa',
#   '81'],
#  ['compared',
#   'to',
#   'an',
#   'average',
#   'industry',
#   'price',
#   'book',
#   'ratio',
#   'of',
#   '60',
#   'is',
#   'valued',
#   'rather',
#   'cheaply'],
#  ['the',
#   'eps',
#   'ha',
#   'been',
#   'growing',
#   'by',
#   '11',
#   '96',
#   'on',
#   'average',
#   'over',
#   'the',
#   'past',
#   'year',
#   'this',
#   'is',
#   'quite',
#   'good'],
#  ['mitch',
#   'did',
#   'great',
#   'job',
#   'of',
#   'getting',
#   'netflix',
#   'started',
#   'he',
#   'clearly',
#   'know',
#   'how',
#   'to',
#   'make',
#   'big',
#   'thing',
#   'happen',
#   'in',
#   'this',
#   'industry'],
#  ['cup',
#   'and',
#   'holder',
#   'inverse',
#   'bearish',
#   'with',
#   '48',
#   '20',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   '16',
#   '16usd'],
#  ['with',
#   'debt',
#   'to',
#   'equity',
#   'ratio',
#   'of',
#   '39',
#   'is',
#   'doing',
#   'better',
#   'than',
#   'the',
#   'average',
#   'in',
#   'the',
#   'industry'],
#  ['sell',
#   'in',
#   'may',
#   'amp',
#   'go',
#   'away',
#   'ha',
#   'been',
#   'pattern',
#   'for',
#   'year',
#   'interesting',
#   'to',
#   'see',
#   'so',
#   'much',
#   'trading',
#   'in',
#   'this',
#   'time',
#   'frame',
#   'bank',
#   'love',
#   'you',
#   'trader'],
#  ['meanwhile', 'in', 'galaxy', 'far', 'far', 'away'],
#  ['broadening',
#   'wedge',
#   'descending',
#   'bearish',
#   'with',
#   '39',
#   '89',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   '34',
#   '22usd'],
#  ['happy', 'trading', 'guy', 'looking', 'to', 'exit', 'today'],
#  ['large', 'put', 'spread', 'in', 'open', 'interest', 'im', 'bearish'],
#  [],
#  ['pt', '29'],
#  ['three',
#   'falling',
#   'peak',
#   'bearish',
#   'with',
#   '38',
#   '36',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   '52',
#   '00usd'],
#  ['happy',
#   'fourth',
#   'everyone',
#   'have',
#   'coke',
#   'and',
#   'smile',
#   'thanks',
#   'for',
#   'the',
#   'dividend',
#   'and'],
#  [],
#  ['selling', 'will', 'prove', 'to', 'be', 'terrible', 'error'],
#  ['the',
#   'end',
#   'of',
#   'the',
#   'article',
#   'just',
#   'posted',
#   'hint',
#   'at',
#   'possible',
#   'acquisition',
#   'of',
#   'sogou',
#   'finger',
#   'crossed'],
#  ['triple',
#   'top',
#   'bearish',
#   'with',
#   '43',
#   '32',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   '834',
#   '81usd'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '80'],
#  ['bro',
#   'that',
#   '39',
#   'not',
#   'how',
#   'it',
#   'work',
#   'delete',
#   'the',
#   'blue',
#   'arrow',
#   'that',
#   '39',
#   'your',
#   'delusion'],
#  ['let',
#   'me',
#   'guess',
#   'everyone',
#   'is',
#   'still',
#   'bullish',
#   'here',
#   'even',
#   'after',
#   'it',
#   'close',
#   'under',
#   'the',
#   '21ma',
#   'on',
#   'the',
#   'daily',
#   'overbought',
#   'level',
#   'trend',
#   'is',
#   'changing'],
#  ['cup',
#   'and',
#   'holder',
#   'bullish',
#   'with',
#   '34',
#   '76',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   '269',
#   '37usd'],
#  ['mr', 'hold', 'yo'],
#  ['option',
#   'volume',
#   'wa',
#   '4x',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   '293',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   '94',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['hi',
#   'everyone',
#   'going',
#   'to',
#   'bed',
#   'good',
#   'night',
#   'everyone',
#   'happy',
#   'money',
#   'monday',
#   'soon',
#   'be',
#   'prepared'],
#  ['2018',
#   '06',
#   '28',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'is',
#   '41'],
#  ['amazon',
#   'new',
#   'warehouse',
#   'policy',
#   'will',
#   'start',
#   'penalizing',
#   'seller',
#   'that',
#   'store',
#   'product',
#   'for',
#   'too',
#   'long'],
#  ['just',
#   'fyi',
#   'trump',
#   'era',
#   'ramp',
#   'up',
#   'tech',
#   'worker',
#   'revolt',
#   'the',
#   'hill'],
#  ['this',
#   'company',
#   'going',
#   'off',
#   'the',
#   'rail',
#   'the',
#   'people',
#   'that',
#   'work',
#   'there',
#   'and',
#   'the',
#   'store',
#   'manager',
#   'say',
#   'it',
#   'all',
#   'circuit',
#   'city',
#   'deux'],
#  ['why',
#   'did',
#   'bank',
#   'fail',
#   'to',
#   'rally',
#   'despite',
#   'huge',
#   'bb',
#   'and',
#   'div',
#   'incr',
#   'me',
#   'thinking',
#   'mm',
#   'driving',
#   'down',
#   'price',
#   'to',
#   'get',
#   'in',
#   'on',
#   'the',
#   'cheap',
#   'prior',
#   'the',
#   'rally'],
#  ['bear',
#   'using',
#   'all',
#   'argument',
#   'sound',
#   'like',
#   'short',
#   'position',
#   'are',
#   'becoming',
#   'loses',
#   'this',
#   'week'],
#  ['gameranx', 'popular', 'youtube', 'gaming', 'channel'],
#  ['facebook', 'the', 'cash', 'machine'],
#  ['and',
#   'it',
#   'will',
#   'take',
#   'all',
#   'semi',
#   '39',
#   'up',
#   'more',
#   'week',
#   'and',
#   'then',
#   'uptrend',
#   'continues'],
#  ['cheap',
#   'dividend',
#   'champion',
#   'with',
#   'low',
#   'forward',
#   '39',
#   'altria',
#   'aflac',
#   'eatonvance'],
#  ['look',
#   'at',
#   'the',
#   'graph',
#   'tripple',
#   'bottom',
#   'reached',
#   'for',
#   'heading',
#   'to',
#   '60',
#   'and',
#   'to',
#   '220',
#   'in',
#   'to',
#   'week'],
#  ['if',
#   'you',
#   'have',
#   'penis',
#   'and',
#   'want',
#   'vagina',
#   'like',
#   'alteration',
#   'go',
#   'get',
#   'job',
#   'at',
#   'sbux'],
#  ['oled',
#   'panel',
#   'post',
#   'steady',
#   'growth',
#   'amid',
#   'weak',
#   'demand',
#   'in',
#   'display',
#   'market',
#   'data'],
#  ['facebook', 'the', 'cash', 'machine'],
#  [],
#  ['option',
#   'volume',
#   'wa',
#   '4x',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   '10',
#   '585',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   '79',
#   'and',
#   'put',
#   'volume',
#   'wa',
#   '21'],
#  ['microsoft',
#   'andromeda',
#   'leak',
#   'foldable',
#   'dual',
#   'screen',
#   'surface',
#   'device',
#   'that',
#   'fit',
#   'in',
#   'your',
#   'pocket'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '47'],
#  ['ha',
#   'good',
#   'piotroski',
#   'score',
#   'of',
#   '00',
#   'this',
#   'indicates',
#   'good',
#   'health',
#   'and',
#   'profitability'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   '14',
#   'at',
#   '2018',
#   '06',
#   '15',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   '79'],
#  ['my',
#   'original',
#   'thesis',
#   'wa',
#   'predicated',
#   'on',
#   'amd',
#   'having',
#   'competitive',
#   'server',
#   'product',
#   'around',
#   'this',
#   'time',
#   'didn',
#   'think',
#   'intel',
#   'would',
#   'shit',
#   'the',
#   'bed'],
#  ['bullish', 'bat', 'bullish', 'bat', 'with', 'bullish', 'divergence'],
#  ['epyc',
#   'server',
#   'adoption',
#   'will',
#   'snow',
#   'ball',
#   'this',
#   'year',
#   'intel',
#   'security',
#   'flaw',
#   '10nm',
#   'fail',
#   'fire',
#   'ceo',
#   'you',
#   'can',
#   'make',
#   'this',
#   'shìt',
#   'up'],
#  ['my',
#   'original',
#   'thesis',
#   'wa',
#   'predicated',
#   'on',
#   'amd',
#   'having',
#   'competitive',
#   'server',
#   'product',
#   'around',
#   'this',
#   'time',
#   'didn',
#   'think',
#   'intel',
#   'would',
#   'shìt',
#   'the',
#   'bed'],
#  ['think', 'will', 'buy', 'a', 'many', 'a', 'can', 'under', '60'],
#  ['new', 'way', 'match', 'group', 'can', 'counter', 'facebook'],
#  ['wowza',
#   'for',
#   'if',
#   'started',
#   'one',
#   'month',
#   'ago',
#   'the',
#   'short',
#   '39',
#   'return',
#   'would',
#   'be',
#   'around',
#   'a',
#   'of',
#   '06',
#   '29',
#   'iex',
#   'data'],
#  ['is',
#   'the',
#   'real',
#   'boom',
#   'in',
#   'the',
#   'social',
#   'medium',
#   'and',
#   'it',
#   'will',
#   'get',
#   'much',
#   'bigger',
#   'it',
#   'will',
#   'be',
#   'in',
#   '280',
#   'before',
#   'christmas'],
#  ['the',
#   'current',
#   'ratio',
#   'of',
#   'is',
#   'much',
#   'better',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of',
#   '07'],
#  ['celgene',
#   'investor',
#   'breathe',
#   'sigh',
#   'of',
#   'relief',
#   'after',
#   'acceleron',
#   '39',
#   'success'],
#  ['bear',
#   'and',
#   'shorties',
#   'made',
#   'huge',
#   'mistake',
#   'and',
#   'they',
#   'don',
#   '39',
#   'have',
#   'the',
#   'money',
#   'to',
#   'buy',
#   'back',
#   'when',
#   'shorted',
#   'it',
#   'at',
#   '170',
#   'so',
#   'they',
#   'cry',
#   'out',
#   'here',
#   'everyday'],
#  ['today', '39', 'insight', 'on'],
#  ['the',
#   'industry',
#   'average',
#   'roa',
#   'is',
#   '78',
#   'outperforms',
#   '81',
#   'of',
#   'it',
#   'industry',
#   'peer'],
#  ['encourage',
#   'you',
#   'to',
#   'no',
#   'longer',
#   'be',
#   'sheep',
#   'end',
#   'your',
#   'racist',
#   'and',
#   'hateful',
#   'way',
#   'buy',
#   'amd',
#   'and',
#   'walk',
#   'away',
#   'from',
#   'the',
#   'democratic',
#   'party',
#   'walkaway'],
#  ['it',
#   '39',
#   'happening',
#   'looking',
#   'to',
#   'ease',
#   'the',
#   'flattening',
#   'of',
#   'the',
#   'yc',
#   'starting',
#   'this',
#   'week',
#   'lot',
#   'of',
#   'trader',
#   'def',
#   'offside',
#   'now'],
#  ['daily', 'or', 'weekly', 'chart', 'all', 'look', 'horrible'],
#  ['if', 'spotify', 'add', 'more', 'video', 'content', 'look', 'out'],
#  ['market',
#   'positioning',
#   'is',
#   'very',
#   'underweight',
#   'crowdthnk',
#   '39',
#   'algo',
#   'forecast',
#   '57',
#   'chance',
#   'moving',
#   'lower'],
#  ['added',
#   'more',
#   'at',
#   '236',
#   'this',
#   'no',
#   'brainer',
#   'if',
#   'you',
#   '39',
#   're',
#   'long',
#   'there',
#   'is',
#   'no',
#   'peer',
#   'and',
#   'they',
#   'are',
#   'top',
#   'dog',
#   'amd',
#   'and',
#   'mu',
#   'notwithstanding'],
#  ['bearish',
#   'bat',
#   'bearish',
#   'bat',
#   'with',
#   'some',
#   'serious',
#   'bearish',
#   'divergence',
#   'something',
#   'is',
#   'about',
#   'to',
#   'give'],
#  ['ha',
#   'been',
#   '50',
#   '50',
#   'proposition',
#   'in',
#   'july',
#   'since',
#   '2014',
#   'with',
#   'net',
#   'return',
#   'of',
#   '01'],
#  ['in',
#   'term',
#   'of',
#   'negative',
#   'for',
#   'there',
#   'are',
#   'bearish',
#   'indicator',
#   'a',
#   'of',
#   '06',
#   '29'],
#  ['quite', 'over', 'valued', 'in', 'my', 'opinion'],
#  ['brexit',
#   'banker',
#   'risk',
#   'life',
#   'on',
#   'the',
#   'edge',
#   'a',
#   'luxembourg',
#   'fill',
#   'up',
#   'via'],
#  ['market', 'history'],
#  ['so', 'amd', 'is', 'using', 'liquid', 'inside', 'of', 'the', 'gpu'],
#  ['curve',
#   'flattening',
#   'juggernaut',
#   'face',
#   'risk',
#   'from',
#   'fed',
#   'concern',
#   'on',
#   'trade',
#   'via'],
#  ['a',
#   'it',
#   'pertains',
#   'to',
#   'if',
#   'started',
#   'day',
#   'ago',
#   'bearish',
#   'investor',
#   'would',
#   'have',
#   'lost',
#   'around',
#   '38',
#   'a',
#   'of',
#   '06',
#   '29',
#   'according',
#   'to',
#   'iex'],
#  [],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '42'],
#  ['study',
#   'of',
#   'watchlist',
#   'trade',
#   'wisely',
#   'invest',
#   'wisely',
#   'read',
#   'the',
#   'wallstreet',
#   'runner'],
#  ['waiting', 'for', 'the', 'pull', 'back', 'slow', 'steady', 'stock'],
#  ['thought',
#   'friday',
#   '39',
#   'flush',
#   'wa',
#   'for',
#   'cheap',
#   'share',
#   'just',
#   'like',
#   'they',
#   'did',
#   'in',
#   'oil',
#   'before',
#   'the',
#   'opec',
#   'meeting'],
#  ['00jeson', 'china', 'attack'],
#  ['2018',
#   '06',
#   '28',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'is',
#   '58'],
#  ['is',
#   'rated',
#   'sell',
#   'since',
#   'june',
#   '19',
#   '2018',
#   'and',
#   'is',
#   '32',
#   'below',
#   'it',
#   'median',
#   'level'],
#  ['dont', 'trust', 'this', 'company'],
#  ['today', '39', 'insight', 'on'],
#  ['the',
#   'anticipation',
#   'is',
#   'rising',
#   'which',
#   'analyst',
#   'is',
#   'right',
#   'june'],
#  ['sorry',
#   'itsallaboutheoptions',
#   'stock',
#   'price',
#   'is',
#   '167',
#   '35',
#   'not',
#   '164',
#   'so',
#   'we',
#   'are',
#   'higher',
#   'than',
#   'you',
#   'predicted',
#   'not',
#   'lower'],
#  ['warren', 'diggered', 'a', 'they', 'exited'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'at',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '36'],
#  ['another', 'analyst', 'opinion', 'on', 'june'],
#  [],
#  ['and',
#   'are',
#   'all',
#   'down',
#   'because',
#   'of',
#   'trade',
#   'concern',
#   'will',
#   'still',
#   'be',
#   'worth',
#   'it',
#   'weight',
#   'in',
#   'faucet',
#   'and',
#   'now',
#   'little',
#   'bit',
#   'of',
#   'lighting'],
#  ['three',
#   'falling',
#   'peak',
#   'bearish',
#   'with',
#   '43',
#   '85',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   '46',
#   '30usd'],
#  ['2018',
#   '06',
#   '28',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'is',
#   '38'],
#  ['rectangle',
#   'top',
#   'bullish',
#   'with',
#   '29',
#   '92',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   '284',
#   '30usd'],
#  ['any', 'more', 'really', 'jetsonbs', 'design', 'they', 'announce'],
#  ['bull',
#   'have',
#   'reason',
#   'on',
#   '06',
#   '29',
#   'to',
#   'pay',
#   'more',
#   'attention'],
#  ['cogsworth', 'cog', 'will', 'take', 'on', 'boeing', 'soon', 'right'],
#  ['really',
#   'baked',
#   'right',
#   'now',
#   'having',
#   'deep',
#   'thought',
#   'short',
#   'coming',
#   'back',
#   'to',
#   'look',
#   'at',
#   'this',
#   'tweet',
#   'in',
#   'year'],
#  ['this',
#   'one',
#   'will',
#   'test',
#   '50',
#   'if',
#   '50',
#   'fails',
#   'my',
#   'target',
#   'is',
#   '45',
#   'to',
#   'start',
#   'buying',
#   'this',
#   'again',
#   'houseofpain'],
#  [],
#  ['making', 'more', 'than', 'ever', 'thanks', 'to', 'amp'],
#  [],
#  ['atl', 'fed', 'forecast', 'whew', 'baby', 'up', 'we', 'go'],
#  ['here',
#   'it',
#   'is',
#   'june',
#   'grr',
#   'date',
#   'is',
#   '2018',
#   'came',
#   'out',
#   'early',
#   'read',
#   'away'],
#  ['bull',
#   'have',
#   'reason',
#   'on',
#   '06',
#   '29',
#   'to',
#   'pay',
#   'more',
#   'attention'],
#  ['stericycle',
#   'current',
#   'chance',
#   'of',
#   'distress',
#   'is',
#   'about',
#   '41',
#   'below',
#   'average'],
#  ['ggr', 'is', 'out', 'for', 'june'],
#  ['today', '39', 'insight', 'on'],
#  ['fyi'],
#  ['will', 'this', 'go', 'over', '200', 'before', 'earnings'],
#  ['extremely',
#   'undervalued',
#   'this',
#   'will',
#   'be',
#   '90',
#   'within',
#   'year',
#   'great',
#   'for',
#   'midterm',
#   'investment'],
#  ['may', 'go', 'slightly', 'down', 'on', 'this', 'news', 'june', 'ggr'],
#  ['stupid', 'spammer', 'wasting', 'time'],
#  ['but',
#   'it',
#   '39',
#   'already',
#   'oversold',
#   'so',
#   'not',
#   'much',
#   'consolidation',
#   'and',
#   'then',
#   'up'],
#  ['this', 'is', 'just', 'the', 'start'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   '58',
#   'at',
#   '2018',
#   '06',
#   '15',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   '08'],
#  ['purchasing',
#   'pill',
#   'pack',
#   'last',
#   'thursday',
#   'and',
#   'breaking',
#   'into',
#   'the',
#   'pharmaceutical',
#   'field',
#   'increase',
#   'amazon',
#   '39',
#   'bottom',
#   'line',
#   'will',
#   'retest',
#   '1763',
#   'quickly'],
#  ['june',
#   'ggr',
#   'up',
#   '12',
#   'still',
#   'after',
#   'the',
#   'soccer',
#   'world',
#   'cup',
#   'and',
#   'holiday'],
#  ['purchasing',
#   'pill',
#   'pack',
#   'last',
#   'thurs',
#   'amp',
#   'breaking',
#   'into',
#   'the',
#   'pharmaceutical',
#   'field',
#   'increase',
#   'amazon',
#   '39',
#   'bottom',
#   'line',
#   'will',
#   'retest',
#   '1763',
#   'quickly'],
#  ['buy', 'back', 'they', 'want', 'cheap'],
#  ['not',
#   'too',
#   'expensive',
#   'and',
#   'growing',
#   'strongly',
#   'check',
#   'out',
#   'now',
#   'part',
#   'of',
#   'our',
#   'affordable',
#   'growth',
#   'selection'],
#  ['option',
#   'volume',
#   'wa',
#   '4x',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   '40',
#   '397',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   '63',
#   'and',
#   'put',
#   'volume',
#   'wa',
#   '37'],
#  ['the',
#   'long',
#   'term',
#   'trend',
#   'is',
#   'positive',
#   'and',
#   'the',
#   'short',
#   'term',
#   'trend',
#   'is',
#   'neutral',
#   'so',
#   'the',
#   'benefit',
#   'of',
#   'the',
#   'doubt',
#   'for',
#   'now'],
#  ['lot',
#   'of',
#   'buyer',
#   'fri',
#   'when',
#   'mm',
#   '39',
#   'pinned',
#   'at',
#   '1700',
#   'quot',
#   'trader',
#   'buy',
#   'amazon',
#   'com',
#   'amzn',
#   'on',
#   'weakness',
#   'quot'],
#  ['in',
#   'term',
#   'of',
#   'positive',
#   'for',
#   'there',
#   'are',
#   'bullish',
#   'indicator',
#   'a',
#   'of',
#   '06',
#   '29'],
#  ['know', 'what', 'hold'],
#  ['never',
#   'have',
#   'seen',
#   'right',
#   'angle',
#   'in',
#   'apple',
#   'lol',
#   'that',
#   'wa',
#   'crazy'],
#  ['wanna',
#   'hear',
#   'the',
#   'er',
#   'ok',
#   'yeah',
#   'all',
#   'got',
#   'great',
#   'product',
#   'so',
#   'what',
#   'this',
#   'is',
#   'the',
#   'stock',
#   'market',
#   'want',
#   'report',
#   'what',
#   'the',
#   'news'],
#  ['starbucks',
#   'to',
#   'become',
#   'the',
#   'pioneer',
#   'in',
#   'medical',
#   'coverage',
#   'for',
#   'sex',
#   'change',
#   'get',
#   'your',
#   'free',
#   'sex',
#   'change',
#   'here'],
#  ['today', '39', 'insight', 'on'],
#  ['today', '39', 'insight', 'on'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '33'],
#  ['39',
#   'all',
#   'in',
#   'on',
#   'august',
#   '17',
#   'call',
#   '39',
#   'either',
#   'gonna',
#   'make',
#   'fortune',
#   'or',
#   'declare',
#   'bankruptcy'],
#  ['wtf'],
#  [],
#  ['macau', 'casino', 'ggr', 'up', 'nearly', '13pct', 'in', 'june', 'govt'],
#  ['jul',
#   '01',
#   '2018',
#   'casino',
#   'gross',
#   'gaming',
#   'revenue',
#   'ggr',
#   'in',
#   'macau',
#   'rose',
#   'by',
#   '12',
#   'percent',
#   'year',
#   'on',
#   'year',
#   'in',
#   'june',
#   'to'],
#  ['what'],
#  ['is', 'gonna', 'be', 'cheaper', 'than', 'also'],
#  ['the',
#   'monster',
#   '32',
#   'core',
#   'amd',
#   'ryzen',
#   'threadripper',
#   '2990x',
#   'cpu',
#   '32c',
#   '64t',
#   'rumored',
#   '1750',
#   'usd'],
#  ['we',
#   'have',
#   'detected',
#   'negative',
#   'indicator',
#   'a',
#   'of',
#   '06',
#   '29',
#   'for',
# ...
#   'all',
#   'sma',
#   'in',
#   'falling',
#   'wedge',
#   'bearish',
#   'until',
#   'breakout'],
#  ['think',
#   'most',
#   'of',
#   'the',
#   'peep',
#   'on',
#   'here',
#   'have',
#   'blocked',
#   'bro',
#   'time',
#   'to',
#   'use',
#   'an',
#   'alternate',
#   'account',
#   'are',
#   'taken'],
#  ['you',
#   'bet',
#   'how',
#   'about',
#   'show',
#   'some',
#   'fact',
#   'sport',
#   'now',
#   'ha',
#   'control',
#   'of',
#   'nfl',
#   'mlb',
#   'march',
#   'madness',
#   'etc',
#   'roku',
#   'suck',
#   'donkey',
#   'dks'],
#  ['alibaba', 'buy', 'stake', 'in', 'turkey', 'trendyol'],
#  ['think',
#   'the',
#   'whole',
#   'dump',
#   'for',
#   'the',
#   'past',
#   'few',
#   'year',
#   'wa',
#   'absolutely',
#   'necessary',
#   'their',
#   'sht',
#   'wa',
#   'getting',
#   'way',
#   'too',
#   'expensive',
#   'they',
#   'can',
#   'grow',
#   'bter',
#   'now'],
#  ['if', 'feel', 'good', 'to', 'be', '90', 'right', 'with', 'this', 'stock'],
#  ['remember',
#   'even',
#   'the',
#   'capital',
#   'investment',
#   'will',
#   'only',
#   'be',
#   'in',
#   '55',
#   'dividend',
#   'payout'],
#  ['since',
#   'last',
#   'er',
#   'stock',
#   'dropped',
#   '11',
#   'reporting',
#   'earnings',
#   'on',
#   '13',
#   'before',
#   'open',
#   'confirmed'],
#  ['whats',
#   'up',
#   'bro',
#   'you',
#   'still',
#   'trade',
#   'this',
#   'stock',
#   'or',
#   'did',
#   'you',
#   'give',
#   'up'],
#  ['short',
#   'volume',
#   'percent',
#   'for',
#   'wa',
#   '21',
#   '64',
#   'on',
#   '06',
#   '28',
#   '18'],
#  ['bull',
#   'have',
#   'reason',
#   'on',
#   '06',
#   '29',
#   'to',
#   'pay',
#   'more',
#   'attention'],
#  ['talking',
#   'about',
#   'gravity',
#   'in',
#   'stock',
#   'market',
#   'is',
#   'fool',
#   'errond',
#   'take',
#   'look',
#   'at'],
#  ['read',
#   'your',
#   'comment',
#   'on',
#   'on',
#   'seeking',
#   'alpha',
#   'you',
#   'know',
#   'lot',
#   'about',
#   'casino',
#   'stock',
#   'will',
#   'this',
#   'ggr',
#   'hurt',
#   'the',
#   'price',
#   'more',
#   'or',
#   'ok',
#   'here'],
#  ['170', 'open', 'tomorrow'],
#  ['12',
#   'is',
#   'more',
#   'then',
#   'enough',
#   'we',
#   'should',
#   'be',
#   'at',
#   '180',
#   'and',
#   'earning',
#   'are',
#   'coming',
#   'up'],
#  ['should', 'be', 'loading', 'on', 'on', 'this', 'stock', 'here'],
#  ['wall',
#   'street',
#   'is',
#   'full',
#   'of',
#   'idiot',
#   'who',
#   'gamble',
#   'until',
#   'they',
#   'lose',
#   '100'],
#  ['hope',
#   'citibank',
#   'go',
#   'bankrupt',
#   'stealing',
#   'money',
#   'by',
#   'nickel',
#   'and',
#   'dimming',
#   'costumer',
#   'with',
#   'stupid',
#   'little',
#   'fee'],
#  [],
#  ['don',
#   'worry',
#   'scumbags',
#   'at',
#   'citibank',
#   'll',
#   'make',
#   'more',
#   'money',
#   'shorting',
#   'your',
#   'stock',
#   'to',
#   'the',
#   'ground',
#   'than',
#   'you',
#   'will',
#   'make',
#   'from',
#   'fee'],
#  ['choppy',
#   'head',
#   'amp',
#   'shoulder',
#   'watch',
#   'for',
#   'the',
#   'breakdown',
#   'watch',
#   'for',
#   'the',
#   'breakdown'],
#  ['releasing',
#   'earnings',
#   'on',
#   '13',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings'],
#  [],
#  ['it', 'is', 'now', 'time', 'for', 'the', 'trumpy', 'bear', 'market'],
#  ['gravity',
#   'applies',
#   'to',
#   'overbot',
#   'condition',
#   'and',
#   'applied',
#   'to',
#   'in',
#   'past',
#   'a',
#   'well'],
#  ['highlight', 'in', 'cancer', 'from', 'the', 'week'],
#  ['jcp', 'jcpenney', 'ha', 'rev', 'per', 'employee', 'of', '124', '000'],
#  ['vrsk',
#   'beta',
#   'of',
#   'veriskanalytics',
#   'is',
#   '56',
#   'making',
#   'it',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market'],
#  ['viavisolutions', 'dipped', 'by', '75', 'in', 'the', 'last', 'year', 'viav'],
#  ['it', 'gartner', 'ha', 'very', 'low', 'roce', 'of', '66'],
#  ['etn',
#   'the',
#   'rpe',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'eatonplc',
#   'is',
#   '217',
#   '000'],
#  ['rrdonnelleysons',
#   'is',
#   'oversold',
#   'according',
#   'to',
#   'it',
#   'stoch',
#   'rsi',
#   '14',
#   'of',
#   '15',
#   '27',
#   'rrd'],
#  ['ba', 'the', 'payout', 'ratio', 'of', 'boeing', 'is', '39', '69'],
#  ['releasing',
#   'earnings',
#   'on',
#   '16',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings'],
#  ['psx', 'fcf', 'of', 'phillips66', 'is', '17', '47'],
#  ['citigroup', 'ha', 'recommendation', 'mean', 'of', '10'],
#  ['mco',
#   'sma',
#   '50',
#   'of',
#   'moody',
#   'is',
#   '173',
#   '71',
#   'now',
#   'down',
#   'by',
#   '81',
#   'and',
#   'sma',
#   '200',
#   'is',
#   '164',
#   '15',
#   'now',
#   'up',
#   'by',
#   '90'],
#  ['fslr',
#   'the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   '12',
#   '26',
#   'of',
#   'firstsolar',
#   'is',
#   '02'],
#  ['aonplc',
#   'ha',
#   'beta',
#   'of',
#   '79',
#   'making',
#   'it',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'aon'],
#  ['microsoft',
#   'ha',
#   'adx',
#   '14',
#   'of',
#   '18',
#   '64',
#   'hinting',
#   'it',
#   'weak',
#   'trend',
#   'msft'],
#  ['apa',
#   'apache',
#   'ha',
#   'sma',
#   '50',
#   'of',
#   '42',
#   '61',
#   'now',
#   'up',
#   'by',
#   '73',
#   'and',
#   'sma',
#   '200',
#   'of',
#   '40',
#   '92',
#   'now',
#   'up',
#   'by',
#   '14',
#   '24'],
#  ['yte', 'ha', 'ppo', '12', '26', 'of', '66', 'incy'],
#  ['jmsmucker', 'ha', 'recommendation', 'mean', 'of', '00', 'sjm'],
#  ['tel', 'teconnectivity', 'ha', 'ppo', '12', '26', 'of'],
#  ['operating',
#   'margin',
#   'of',
#   'internationalbusinessmachines',
#   'is',
#   '15',
#   '11',
#   'ibm'],
#  ['northerntrust', 'ha', 'recommendation', 'mean', 'of', '50', 'ntrs'],
#  ['bankofnewyorkmellon', 'ha', 'short', 'of', 'float', 'of', '39', 'bk'],
#  ['nowhere',
#   'to',
#   'go',
#   'but',
#   'up',
#   'focus',
#   'on',
#   'fundamental',
#   'epyc',
#   'v',
#   'xeon',
#   'tam',
#   'all',
#   'revenue',
#   'and',
#   'profit',
#   'coming',
#   'now',
#   '2018',
#   'revenue',
#   'ramp',
#   'year',
#   '27',
#   'pt'],
#  ['etfc', 'insider', 'ownership', 'of', 'etrade', 'is', '26'],
#  ['envisionhealthcare',
#   'ha',
#   'short',
#   'of',
#   'float',
#   'of',
#   '26',
#   '26',
#   'evhc'],
#  ['baxterinternational',
#   'is',
#   'overbought',
#   'with',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   '12',
#   '26',
#   'of',
#   '27',
#   'bax'],
#  ['profit', 'margin', 'of', 'att', 'is', '19', '25'],
#  ['eogresources',
#   'is',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'with',
#   'beta',
#   'of',
#   '21',
#   'eog'],
#  ['diamondoffshoredrilling',
#   'ha',
#   'adx',
#   '14',
#   'of',
#   '17',
#   '66',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'do'],
#  ['the', 'dividend', 'yield', 'of', 'averydennison', 'is', '08', 'avy'],
#  ['southern',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'capital',
#   'employed',
#   'of',
#   '93',
#   'so'],
#  ['insider', 'ownership', 'of', 'davita', 'is', '16', 'dva'],
#  ['western',
#   'ma',
#   'berkshire',
#   'cty',
#   'today',
#   'already',
#   '94',
#   'deg',
#   'today',
#   'the',
#   'cool',
#   'end',
#   'of',
#   'the',
#   'state'],
#  ['citizen', 'ha', 'stoch', '14', 'of', 'making', 'it', 'oversold', 'cfg'],
#  ['bear',
#   'have',
#   'lost',
#   '29',
#   'on',
#   '06',
#   '29',
#   'alone',
#   'in',
#   'according',
#   'to',
#   'iex',
#   'data'],
#  ['cimarexco',
#   'ha',
#   'adx',
#   '14',
#   'of',
#   '22',
#   '28',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'xec'],
#  ['all',
#   'allstate',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   '15',
#   '61'],
#  ['cxo',
#   'conchoresources',
#   'went',
#   'up',
#   'by',
#   '13',
#   '84',
#   'in',
#   'the',
#   'last',
#   'year'],
#  ['compared',
#   'to',
#   'an',
#   'average',
#   'enterprise',
#   'value',
#   'to',
#   'ebitda',
#   'ratio',
#   'of',
#   '13',
#   '28',
#   'is',
#   'valued',
#   'rather',
#   'cheaply'],
#  ['bull',
#   'have',
#   'reason',
#   'on',
#   '06',
#   '29',
#   'to',
#   'pay',
#   'more',
#   'attention'],
#  ['qepresources',
#   'ha',
#   'very',
#   'high',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   '487',
#   '000',
#   'qep'],
#  ['ans', 'fcf', 'of', 'ansys', 'is', '194', '66'],
#  ['coty', 'the', 'recommendation', 'mean', 'of', 'coty', 'is', '40'],
#  ['mtd',
#   'profit',
#   'margin',
#   'of',
#   'mettler',
#   'toledointernational',
#   'is',
#   '13',
#   '50'],
#  ['anyone', 'know', 'what', 'this', 'is', 'referring', 'to'],
#  ['gross', 'margin', 'of', 'motorolasolutions', 'is', '46', '05', 'msi'],
#  ['operating', 'margin', 'of', 'michaelkors', 'is', '18', '73', 'kor'],
#  ['allegionplc',
#   'is',
#   'overbought',
#   'according',
#   'to',
#   'it',
#   'stochastic',
#   'rsi',
#   'indicator',
#   '14',
#   'of',
#   '95',
#   '46',
#   'alle'],
#  ['nlsn',
#   'the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   '12',
#   '26',
#   'of',
#   'nielsennv',
#   'is'],
#  ['wpx', 'wpx', 'ha', 'rev', 'per', 'employee', 'of', '437', '000'],
#  ['whr', 'whirlpool', 'ha', 'dividend', 'yield', 'of', '95'],
#  ['chrw', 'chrobinsonworldwide', 'ha', 'short', 'of', 'float', 'of', '78'],
#  ['the', 'recommendation', 'mean', 'of', 'wellsfargo', 'is', '60', 'wfc'],
#  ['ccl', 'carnival', 'ha', 'operating', 'margin', 'of', '18', '26'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   '2018',
#   '06',
#   '28',
#   'is',
#   '37'],
#  ['sma',
#   '50',
#   'of',
#   'pepsico',
#   'is',
#   '102',
#   '84',
#   'now',
#   'up',
#   'by',
#   '86',
#   'and',
#   'sma',
#   '200',
#   'is',
#   '109',
#   '29',
#   'now',
#   'down',
#   'by',
#   '39',
#   'pep'],
#  ['pfe',
#   'pfizer',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   '33',
#   '71'],
#  ['so',
#   'funny',
#   'how',
#   'bear',
#   'disappear',
#   'from',
#   'to',
#   '17',
#   'but',
#   'it',
#   'pull',
#   'back',
#   'to',
#   '15',
#   'and',
#   'the',
#   'sky',
#   'is',
#   'falling',
#   'lollll',
#   'the',
#   'nature',
#   'of',
#   'stock',
#   'is',
#   'up',
#   'and',
#   'down'],
#  ['deltaairlines',
#   'ha',
#   'adx',
#   '14',
#   'of',
#   '23',
#   '35',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'dal'],
#  ['adtalemglobaleducation',
#   'ha',
#   'operating',
#   'margin',
#   'of',
#   '13',
#   '46',
#   'atge'],
#  ['bsx',
#   'bostonscientific',
#   'ha',
#   'institutional',
#   'ownership',
#   'of',
#   '93',
#   '57'],
#  ['mck',
#   'mckesson',
#   'went',
#   'down',
#   'by',
#   '18',
#   '93',
#   'in',
#   'the',
#   'last',
#   'year'],
#  ['pbct',
#   'peoplesunited',
#   'is',
#   'overbought',
#   'with',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   '12',
#   '26',
#   'of',
#   '98'],
#  ['insider',
#   'ownership',
#   'of',
#   'vertexpharmaceuticalsorporated',
#   'is',
#   '45',
#   'vrtx'],
#  ['bkng', 'volatility', 'of', 'booking', 'is', '75'],
#  ['dis', 'waltdisney', 'ha', 'ppo', '12', '26', 'of', '15'],
#  ['abbottlaboratories', 'ha', 'insider', 'ownership', 'of', '72', 'abt'],
#  ['arthurjgallagherco',
#   'ha',
#   'adx',
#   '14',
#   'of',
#   '25',
#   '59',
#   'signifying',
#   'it',
#   'strong',
#   'trend',
#   'ajg'],
#  ['disca',
#   'discoverycommunications',
#   'ha',
#   'gross',
#   'margin',
#   'of',
#   '55',
#   '73'],
#  ['lyondellbasellindustriesnv',
#   'ha',
#   'weak',
#   'trend',
#   'according',
#   'to',
#   'it',
#   'adx',
#   '14',
#   'of',
#   '18',
#   'lyb'],
#  ['so',
#   'basically',
#   'the',
#   'vip',
#   'and',
#   'premium',
#   'mass',
#   'aren',
#   'spending',
#   'a',
#   'much',
#   'analyst',
#   'fooled',
#   'by',
#   'the',
#   'appearance',
#   'given',
#   'by',
#   'lower',
#   'quality',
#   'mass'],
#  ['skyworkssolutions',
#   'ha',
#   'institutional',
#   'ownership',
#   'of',
#   '84',
#   '84',
#   'swks'],
#  ['edisoninternational',
#   'ha',
#   'adx',
#   '14',
#   'of',
#   '22',
#   '41',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'eix'],
#  ['wmb', 'williamscompanies', 'ha', 'volatility', 'of', '92'],
#  ['is',
#   'the',
#   'competition',
#   'profitable',
#   'yes',
#   'are',
#   'they',
#   'collaboration',
#   'with',
#   'waymo',
#   'yes',
#   'do',
#   'they',
#   'have',
#   'cash',
#   'yes'],
#  ['releasing',
#   'earnings',
#   'on',
#   '16',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings'],
#  ['kroger', 'ha', 'very', 'high', 'roce', 'of', '10', '75', 'kr'],
#  ['pcar', 'institutional', 'ownership', 'of', 'paccar', 'is', '67', '26'],
#  ['fcf', 'of', 'citrixsystems', 'is', '15', '12', 'ctxs'],
#  ['profit', 'margin', 'of', 'verisign', 'is', '39', '24', 'vrsn'],
#  ['honeywellinternational',
#   'ha',
#   'beta',
#   'of',
#   '06',
#   'making',
#   'it',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'hon'],
#  ['the', 'dividend', 'yield', 'of', 'lincolnnational', 'is', '13', 'lnc'],
#  ['txn',
#   'texasinstrumentsorporated',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   '35',
#   '39'],
#  ['tdc',
#   'short',
#   'percent',
#   'of',
#   'float',
#   'of',
#   'teradata',
#   'is',
#   '20',
#   '72'],
#  ['sma',
#   '50',
#   'of',
#   'smithao',
#   'is',
#   '62',
#   '74',
#   'now',
#   'down',
#   'by',
#   '72',
#   'and',
#   'sma',
#   '200',
#   'is',
#   '63',
#   '53',
#   'now',
#   'down',
#   'by',
#   '90',
#   'aos'],
#  ['idexxlaboratories', 'ha', 'operating', 'margin', 'of', '21', '22', 'idxx'],
#  ['bby', 'bestbuyco', 'ha', 'revenue', 'per', 'employee', 'of', '342', '000'],
#  ['masco', 'ha', 'gross', 'margin', 'of', '33', '53', 'ma'],
#  ['the', 'payout', 'ratio', 'of', 'nike', 'is', '70', '37', 'nke'],
#  ['len', 'lennar', 'rose', 'by', '28', 'in', 'the', 'last', '12', 'month'],
#  ['clf', 'the', 'roce', 'of', 'cliffsnaturalresources', 'is', '82'],
#  ['totalsystemservices',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   '26',
#   '43',
#   'tss'],
#  ['symantec', 'dipped', 'by', '26', '90', 'in', 'the', 'last', 'year', 'symc'],
#  ['rrc',
#   'rangeresources',
#   'went',
#   'down',
#   'by',
#   '27',
#   '79',
#   'in',
#   'the',
#   'last',
#   '12',
#   'month'],
#  ['nsc',
#   'norfolksouther',
#   'ha',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   '394',
#   '000'],
#  ['the',
#   'return',
#   'on',
#   'capital',
#   'employed',
#   'of',
#   'accentureplc',
#   'is',
#   '35',
#   '76',
#   'acn'],
#  ['willistowerswatsonpublic',
#   'is',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'with',
#   'beta',
#   'of',
#   '95',
#   'wltw'],
#  ['genworth', 'ha', 'institutional', 'ownership', 'of', '68', '78', 'gnw'],
#  ['martinmariettamaterials',
#   'ha',
#   'adx',
#   '14',
#   'of',
#   '26',
#   '44',
#   'signifying',
#   'it',
#   'strong',
#   'trend',
#   'mlm'],
#  ['intc', 'operating', 'margin', 'of', 'intel', 'is', '29', '88'],
#  ['operating', 'margin', 'of', 'affiliatedmanagers', 'is', '34', '94', 'amg'],
#  ['spgi', 'spglobal', 'ha', 'volatility', 'of', '47'],
#  ['fbhs',
#   'beta',
#   'of',
#   'fortunebrandshomesecurity',
#   'is',
#   '29',
#   'making',
#   'it',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market'],
#  ['nwl',
#   'newellbrands',
#   'dipped',
#   'by',
#   '51',
#   '90',
#   'in',
#   'the',
#   'last',
#   'year'],
#  ['coopercompanies', 'ha', 'operating', 'margin', 'of', '22', '24', 'coo'],
#  ['brighthouse',
#   'is',
#   'oversold',
#   'according',
#   'to',
#   'it',
#   'stoch',
#   'rsi',
#   '14',
#   'of',
#   'bhf'],
#  ['ebay',
#   'the',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'ebay',
#   'is',
#   '698',
#   '000'],
#  ['slg', 'operating', 'margin', 'of', 'slgreenrealty', 'is', '29', '95'],
#  ['the', 'recommendation', 'mean', 'of', 'ppgindustries', 'is', '40', 'ppg'],
#  ['tegna',
#   'dipped',
#   'by',
#   '24',
#   '71',
#   'in',
#   'the',
#   'last',
#   '12',
#   'month',
#   'tgna'],
#  ['dollargeneral', 'ha', 'gross', 'margin', 'of', '30', '12', 'dg'],
#  ['beta',
#   'of',
#   'hess',
#   '48',
#   'make',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'he'],
#  ['insider', 'ownership', 'of', 'vulcanmaterials', 'is', '25', 'vmc'],
#  ['jpm',
#   '73',
#   'of',
#   'floating',
#   'share',
#   'of',
#   'jpmorganchaseco',
#   'are',
#   'being',
#   'shorted'],
#  ['beta',
#   'of',
#   'perrigo',
#   'is',
#   '80',
#   'making',
#   'it',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'prgo'],
#  ['mmc',
#   'marshmclennancompanies',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   '22',
#   '24'],
#  ['tsn',
#   'tysonfoods',
#   'ha',
#   'price',
#   'to',
#   'free',
#   'cash',
#   'flow',
#   'ratio',
#   'of',
#   '15',
#   '87'],
#  ['the',
#   'rpe',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'intercontinentalexchange',
#   'is',
#   '961',
#   '000',
#   'ice'],
#  ['bectondickinsonand',
#   'ha',
#   'adx',
#   '14',
#   'of',
#   '24',
#   '91',
#   'hinting',
#   'it',
#   'weak',
#   'trend',
#   'bdx'],
#  ['the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   '12',
#   '26',
#   'of',
#   'fluor',
#   'is',
#   'flr'],
#  ['pdco',
#   'pattersoncompanies',
#   'ha',
#   'price',
#   'to',
#   'free',
#   'cash',
#   'flow',
#   'ratio',
#   'of',
#   '11',
#   '80'],
#  ['footlocker', 'rose', 'by', '84', 'in', 'the', 'last', 'year', 'fl'],
#  ['we',
#   'have',
#   'detected',
#   'negative',
#   'indicator',
#   'a',
#   'of',
#   '06',
#   '29',
#   'for',
#   'more',
#   'info',
#   'at'],
#  ['aph', 'amphenol', 'ha', 'fcf', 'of', '32', '68'],
#  ...]

# %% [markdown]
# ### Bag of Words
# Now with all of our messages tokenized, we want to create a vocabulary and count up how often each word appears in our entire corpus. Use the [`Counter`](https://docs.python.org/3.1/library/collections.html#collections.Counter) function to count up all the tokens.

# %%
from collections import Counter


"""
Create a vocabulary by using Bag of words
"""

# TODO: Implement 

bow = dict(Counter(' '.join([' '.join(tokens) for tokens in tokenized]).split()))

# %% [markdown]
# ### Frequency of Words Appearing in Message
# With our vocabulary, now we'll remove some of the most common words such as 'the', 'and', 'it', etc. These words don't contribute to identifying sentiment and are really common, resulting in a lot of noise in our input. If we can filter these out, then our network should have an easier time learning.
#
# We also want to remove really rare words that show up in a only a few twits. Here you'll want to divide the count of each word by the number of messages. Then remove words that only appear in some small fraction of the messages.

# %%
"""
Set the following variables:
    freqs
    low_cutoff
    high_cutoff
    K_most_common
"""
import operator
# TODO Implement 

# Dictionart that contains the Frequency of words appearing in messages.
# The key is the token and the value is the frequency of that word in the corpus.
freqs = {word: count/len(bow) for word, count in bow.items()}

# Float that is the frequency cutoff. Drop words with a frequency that is lower or equal to this number.
low_cutoff = 1e-5

# Integer that is the cut off for most common words. Drop words that are the `high_cutoff` most common words.
high_cutoff = 10

# The k most common words in the corpus. Use `high_cutoff` as the k.
K_most_common = [x[0] for x in sorted(freqs.items(), key=operator.itemgetter(1))[-high_cutoff:]]


filtered_words = [word for word in freqs if (freqs[word] > low_cutoff and word not in K_most_common)]
print(K_most_common)
len(filtered_words)
# Out:
# ['it', 'this', 'in', 'and', 'of', 'on', 'for', 'is', 'to', 'the']
# 59936

# %% [markdown]
# ### Updating Vocabulary by Removing Filtered Words
# Let's creat three variables that will help with our vocabulary.

# %%
"""
Set the following variables:
    vocab
    id2vocab
    filtered
""" 
from tqdm import tqdm
#TODO Implement

# A dictionary for the `filtered_words`. The key is the word and value is an id that represents the word. 
vocab = {word: index for index, word in enumerate(filtered_words, 1)}
# Reverse of the `vocab` dictionary. The key is word id and value is the word. 
id2vocab = {ii: word for word, ii in vocab.items()}
# tokenized with the words not in `filtered_words` removed.
filtered = [[word for word in message if word in vocab] for message in tokenized]

# %% [markdown]
# ### Balancing the classes
# Let's do a few last pre-processing steps. If we look at how our twits are labeled, we'll find that 50% of them are neutral. This means that our network will be 50% accurate just by guessing 0 every single time. To help our network learn appropriately, we'll want to balance our classes.
# That is, make sure each of our different sentiment scores show up roughly as frequently in the data.
#
# What we can do here is go through each of our examples and randomly drop twits with neutral sentiment. What should be the probability we drop these twits if we want to get around 20% neutral twits starting at 50% neutral? We should also take this opportunity to remove messages with length 0.

# %%
balanced = {'messages': [], 'sentiments':[]}

n_neutral = sum(1 for each in sentiments if each == 2)
N_examples = len(sentiments)
keep_prob = (N_examples - n_neutral)/4/n_neutral

for idx, sentiment in enumerate(sentiments):
    message = filtered[idx]
    if len(message) == 0:
        # skip this message because it has length zero
        continue
    elif sentiment != 2 or random.random() < keep_prob:
        balanced['messages'].append(message)
        balanced['sentiments'].append(sentiment)

# %% [markdown]
# If you did it correctly, you should see the following result

# %%
n_neutral = sum(1 for each in balanced['sentiments'] if each == 2)
N_examples = len(balanced['sentiments'])
n_neutral/N_examples
# Out:
# 0.1943156804977045

# %% [markdown]
# Finally let's convert our tokens into integer ids which we can pass to the network.

# %%
token_ids = [[vocab[word] for word in message] for message in balanced['messages']]
sentiments = balanced['sentiments']

# %% [markdown]
# ## Neural Network
# Now we have our vocabulary which means we can transform our tokens into ids, which are then passed to our network. So, let's define the network now!
#
# Here is a nice diagram showing the network we'd like to build:
#
# #### Embed -> RNN -> Dense -> Softmax
# ### Implement the text classifier
# Before we build text classifier, if you remember from the other network that you built in  "Sentiment Analysis with an RNN"  exercise  - which there, the network called " SentimentRNN", here we named it "TextClassifer" - consists of three main parts: 1) init function `__init__` 2) forward pass `forward`  3) hidden state `init_hidden`.
#
# This network is pretty similar to the network you built expect in the  `forward` pass, we use softmax instead of sigmoid. The reason we are not using sigmoid is that the output of NN is not a binary. In our network, sentiment scores have 5 possible outcomes. We are looking for an outcome with the highest probability thus softmax is a better choice.

# %%
class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_size, lstm_size, output_size, lstm_layers=1, dropout=0.1):
        """
        Initialize the model by setting up the layers.
        
        Parameters
        ----------
            vocab_size : The vocabulary size.
            embed_size : The embedding layer size.
            lstm_size : The LSTM layer size.
            output_size : The output size.
            lstm_layers : The number of LSTM layers.
            dropout : The dropout probability.
        """
        
        super().__init__()
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.lstm_size = lstm_size
        self.output_size = output_size
        self.lstm_layers = lstm_layers
        self.dropout = dropout
        
        # TODO Implement

        # Setup embedding layer
        self.embedding = nn.Embedding(vocab_size, embed_size)
        
        # Setup additional layers
        self.lstm = nn.LSTM(embed_size, lstm_size, lstm_layers, 
                            dropout=dropout, batch_first=False)

        # dropout layer
        self.dropout = nn.Dropout(dropout)        
        
        # linear and sigmoid layers
        self.fc = nn.Linear(lstm_size, output_size)
        self.lsof = nn.LogSoftmax()


    def init_hidden(self, batch_size):
        """ 
        Initializes hidden state
        
        Parameters
        ----------
            batch_size : The size of batches.
        
        Returns
        -------
            hidden_state
            
        """
        
        # TODO Implement 
        
        # Create two new tensors with sizes n_layers x batch_size x hidden_dim,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data
        
        hidden = (weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_(),
                      weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_())
        
        return hidden        


    def forward(self, nn_input, hidden_state):
        """
        Perform a forward pass of our model on nn_input.
        
        Parameters
        ----------
            nn_input : The batch of input to the NN.
            hidden_state : The LSTM hidden state.

        Returns
        -------
            logps: log softmax output
            hidden_state: The new hidden state.

        """
        
        # TODO Implement 

        # embeddings and lstm_out
        nn_input = nn_input.long() 
        lstm_out, hidden = self.lstm(self.embedding(nn_input), hidden_state) 
        
        # Softmax function
        logps = self.lsof(self.fc(self.dropout(lstm_out[-1,:,:])) )
        
        # reshape to be batch_size first
        batch_size = nn_input.size(1)       
        
        # return last sigmoid output and hidden state
        return logps, hidden

# %% [markdown]
# ### View Model

# %%
model = TextClassifier(len(vocab), 10, 6, 5, dropout=0.1, lstm_layers=2)
model.embedding.weight.data.uniform_(-1, 1)
input = torch.randint(0, 1000, (5, 4), dtype=torch.int64)
hidden = model.init_hidden(4)

logps, _ = model.forward(input, hidden)
print(logps)
# Out:
# tensor([[-1.7032, -1.6813, -1.7006, -1.4968, -1.4900],
#         [-1.7032, -1.6536, -1.6885, -1.5327, -1.4881],
#         [-1.7235, -1.6400, -1.6748, -1.5221, -1.5052],
#         [-1.7518, -1.6150, -1.6563, -1.5569, -1.4871]])
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:90: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.

# %% [markdown]
# ## Training
# ### DataLoaders and Batching
# Now we should build a generator that we can use to loop through our data. It'll be more efficient if we can pass our sequences in as batches. Our input tensors should look like `(sequence_length, batch_size)`. So if our sequences are 40 tokens long and we pass in 25 sequences, then we'd have an input size of `(40, 25)`.
#
# If we set our sequence length to 40, what do we do with messages that are more or less than 40 tokens? For messages with fewer than 40 tokens, we will pad the empty spots with zeros. We should be sure to **left** pad so that the RNN starts from nothing before going through the data. If the message has 20 tokens, then the first 20 spots of our 40 long sequence will be 0. If a message has more than 40 tokens, we'll just keep the first 40 tokens.

# %%
def dataloader(messages, labels, sequence_length=30, batch_size=32, shuffle=False):
    """ 
    Build a dataloader.
    """
    if shuffle:
        indices = list(range(len(messages)))
        random.shuffle(indices)
        messages = [messages[idx] for idx in indices]
        labels = [labels[idx] for idx in indices]

    total_sequences = len(messages)

    for ii in range(0, total_sequences, batch_size):
        batch_messages = messages[ii: ii+batch_size]
        
        # First initialize a tensor of all zeros
        batch = torch.zeros((sequence_length, len(batch_messages)), dtype=torch.int64)
        for batch_num, tokens in enumerate(batch_messages):
            token_tensor = torch.tensor(tokens)
            # Left pad!
            start_idx = max(sequence_length - len(token_tensor), 0)
            batch[start_idx:, batch_num] = token_tensor[:sequence_length]
        
        label_tensor = torch.tensor(labels[ii: ii+len(batch_messages)])
        
        yield batch, label_tensor

# %% [markdown]
# ### Training and  Validation
# With our data in nice shape, we'll split it into training and validation sets.

# %%
"""
Split data into training and validation datasets. Use an appropriate split size.
The features are the `token_ids` and the labels are the `sentiments`.
"""   

# TODO Implement 

split_percent = 0.7
s_idx = int(len(token_ids)*split_percent)

train_features = token_ids[:s_idx]
valid_features = token_ids[s_idx:]
train_labels   = sentiments[:s_idx]
valid_labels   = sentiments[s_idx:]

# %%
text_batch, labels = next(iter(dataloader(train_features, train_labels, sequence_length=20, batch_size=64)))
model = TextClassifier(len(vocab)+1, 200, 128, 5, dropout=0.)
hidden = model.init_hidden(64)
logps, hidden = model.forward(text_batch, hidden)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:90: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.

# %% [markdown]
# ### Training
# It's time to train the neural network!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = TextClassifier(len(vocab)+1, 1024, 512, 5, lstm_layers=2, dropout=0.2)
model.embedding.weight.data.uniform_(-1, 1)
model.to(device)
# Out:
# TextClassifier(
#   (embedding): Embedding(59937, 1024)
#   (lstm): LSTM(1024, 512, num_layers=2, dropout=0.2)
#   (dropout): Dropout(p=0.2)
#   (fc): Linear(in_features=512, out_features=5, bias=True)
#   (lsof): LogSoftmax()
# )

# %%
"""
Train your model with dropout. Make sure to clip your gradients.
Print the training loss, validation loss, and validation accuracy for every 100 steps.
"""

epochs = 5
batch_size = 512
learning_rate = 0.001

clip=5

print_every = 100
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
model.train()

for epoch in range(epochs):
    print('Starting epoch {}'.format(epoch + 1))
    
    steps = 0
    for text_batch, labels in dataloader(
            train_features, train_labels, batch_size=batch_size, sequence_length=20, shuffle=True):
        steps += 1
        hidden = model.init_hidden(labels.shape[0])

        # Set Device
        text_batch, labels = text_batch.to(device), labels.to(device)
        for each in hidden:
            each.to(device)
        # TODO Implement: Train Model
        model.zero_grad()
        
        output, hidden = model(text_batch, hidden)     
        
        # calculate the loss and perform backprop
        loss = criterion(output.squeeze(), labels)
        loss.backward()       
        
        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()          
        
        # TODO Implement: Train Model
        
        
        if steps % print_every == 0:
            model.eval()
            
            # TODO Implement: Print metrics   
            
            model.train()
            print("Epoch: {}/{}...".format(epoch+1, epochs),
                  "Step: {}...".format(steps),
                  "Loss: {:.6f}...".format(loss.item()) )
# Out:
# Starting epoch 1
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:90: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Epoch: 1/5... Step: 100... Loss: 0.930494...
# Epoch: 1/5... Step: 200... Loss: 0.875862...
# Epoch: 1/5... Step: 300... Loss: 0.834917...
# Epoch: 1/5... Step: 400... Loss: 0.778110...
# Epoch: 1/5... Step: 500... Loss: 0.799623...
# Epoch: 1/5... Step: 600... Loss: 0.729880...
# Epoch: 1/5... Step: 700... Loss: 0.756174...
# Epoch: 1/5... Step: 800... Loss: 0.730593...
# Epoch: 1/5... Step: 900... Loss: 0.701013...
# Epoch: 1/5... Step: 1000... Loss: 0.705424...
# Epoch: 1/5... Step: 1100... Loss: 0.656983...
# Epoch: 1/5... Step: 1200... Loss: 0.655887...
# Epoch: 1/5... Step: 1300... Loss: 0.702275...
# Epoch: 1/5... Step: 1400... Loss: 0.643036...
# Starting epoch 2
# Epoch: 2/5... Step: 100... Loss: 0.609344...
# Epoch: 2/5... Step: 200... Loss: 0.632403...
# Epoch: 2/5... Step: 300... Loss: 0.610758...
# Epoch: 2/5... Step: 400... Loss: 0.590510...
# Epoch: 2/5... Step: 500... Loss: 0.622780...
# Epoch: 2/5... Step: 600... Loss: 0.629066...
# Epoch: 2/5... Step: 700... Loss: 0.618205...
# Epoch: 2/5... Step: 800... Loss: 0.601816...
# Epoch: 2/5... Step: 900... Loss: 0.583444...
# Epoch: 2/5... Step: 1000... Loss: 0.602980...
# Epoch: 2/5... Step: 1100... Loss: 0.612645...
# Epoch: 2/5... Step: 1200... Loss: 0.573506...
# Epoch: 2/5... Step: 1300... Loss: 0.635022...
# Epoch: 2/5... Step: 1400... Loss: 0.666039...
# Starting epoch 3
# Epoch: 3/5... Step: 100... Loss: 0.532847...
# Epoch: 3/5... Step: 200... Loss: 0.510711...
# Epoch: 3/5... Step: 300... Loss: 0.452575...
# Epoch: 3/5... Step: 400... Loss: 0.454159...
# Epoch: 3/5... Step: 500... Loss: 0.561601...
# Epoch: 3/5... Step: 600... Loss: 0.520095...
# Epoch: 3/5... Step: 700... Loss: 0.597918...
# Epoch: 3/5... Step: 800... Loss: 0.542410...
# Epoch: 3/5... Step: 900... Loss: 0.556350...
# Epoch: 3/5... Step: 1000... Loss: 0.565292...
# Epoch: 3/5... Step: 1100... Loss: 0.597233...
# Epoch: 3/5... Step: 1200... Loss: 0.532118...
# Epoch: 3/5... Step: 1300... Loss: 0.497806...
# Epoch: 3/5... Step: 1400... Loss: 0.595607...
# Starting epoch 4
# Epoch: 4/5... Step: 100... Loss: 0.403141...
# Epoch: 4/5... Step: 200... Loss: 0.394616...
# Epoch: 4/5... Step: 300... Loss: 0.396263...
# Epoch: 4/5... Step: 400... Loss: 0.472513...
# Epoch: 4/5... Step: 500... Loss: 0.415770...
# Epoch: 4/5... Step: 600... Loss: 0.447867...
# Epoch: 4/5... Step: 700... Loss: 0.471382...
# Epoch: 4/5... Step: 800... Loss: 0.457870...
# Epoch: 4/5... Step: 900... Loss: 0.433219...
# Epoch: 4/5... Step: 1000... Loss: 0.369008...
# Epoch: 4/5... Step: 1100... Loss: 0.469993...
# Epoch: 4/5... Step: 1200... Loss: 0.502174...
# Epoch: 4/5... Step: 1300... Loss: 0.476304...
# Epoch: 4/5... Step: 1400... Loss: 0.465759...
# Starting epoch 5
# Epoch: 5/5... Step: 100... Loss: 0.305348...
# Epoch: 5/5... Step: 200... Loss: 0.364150...
# Epoch: 5/5... Step: 300... Loss: 0.379681...
# Epoch: 5/5... Step: 400... Loss: 0.387928...
# Epoch: 5/5... Step: 500... Loss: 0.379313...
# Epoch: 5/5... Step: 600... Loss: 0.352920...
# Epoch: 5/5... Step: 700... Loss: 0.325067...
# Epoch: 5/5... Step: 800... Loss: 0.376731...
# Epoch: 5/5... Step: 900... Loss: 0.403588...
# Epoch: 5/5... Step: 1000... Loss: 0.436474...
# Epoch: 5/5... Step: 1100... Loss: 0.385844...
# Epoch: 5/5... Step: 1200... Loss: 0.385579...
# Epoch: 5/5... Step: 1300... Loss: 0.375313...
# Epoch: 5/5... Step: 1400... Loss: 0.411426...

# %% [markdown]
# ## Making Predictions
# ### Prediction
# Okay, now that you have a trained model, try it on some new twits and see if it works appropriately. Remember that for any new text, you'll need to preprocess it first before passing it to the network. Implement the `predict` function to generate the prediction vector from a message.

# %%
import numpy as np
def predict(text, model, vocab):
    """ 
    Make a prediction on a single sentence.

    Parameters
    ----------
        text : The string to make a prediction on.
        model : The model to use for making the prediction.
        vocab : Dictionary for word to word ids. The key is the word and the value is the word id.

    Returns
    -------
        pred : Prediction vector
    """    
    
    # TODO Implement
    
    tokens = preprocess(text)
    
    # Filter non-vocab words
    # Convert words to ids 
    # Adding a batch dimension 
    # Get the NN output 
    logps, _ = model.forward(torch.from_numpy(np.asarray(torch.FloatTensor([vocab[token] for token in tokens if token in vocab] ).view(-1, 1))), model.init_hidden(1))
    # Take the exponent of the NN output to get a range of 0 to 1 for each label. 
    
    return torch.exp(logps)

# %%
text = "Google is working on self driving cars, I'm bullish on $goog"
model.eval()
model.to("cpu")
predict(text, model, vocab)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:90: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# tensor([[ 4.2999e-06,  7.6864e-04,  1.1475e-03,  5.9810e-01,  3.9998e-01]])

# %% [markdown]
# ### Questions: What is the prediction of the model? What is the uncertainty of the prediction?
# ** TODO: Answer Question**

# %% [markdown]
# Now we have a trained model and we can make predictions. We can use this model to track the sentiments of various stocks by predicting the sentiments of twits as they are coming in. Now we have a stream of twits. For each of those twits, pull out the stocks mentioned in them and keep track of the sentiments. Remember that in the twits, ticker symbols are encoded with a dollar sign as the first character, all caps, and 2-4 letters, like $AAPL. Ideally, you'd want to track the sentiments of the stocks in your universe and use this as a signal in your larger model(s).
#
# ## Testing
# ### Load the Data

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'test_twits.json'), 'r') as f:
    test_data = json.load(f)

# %% [markdown]
# ### Twit Stream

# %%
def twit_stream():
    for twit in test_data['data']:
        yield twit

next(twit_stream())
# Out:
# {'message_body': '$JWN has moved -1.69% on 10-31. Check out the movement and peers at  https://dividendbot.com?s=JWN',
#  'timestamp': '2018-11-01T00:00:05Z'}

# %% [markdown]
# Using the `prediction` function, let's apply it to a stream of twits.

# %%
def score_twits(stream, model, vocab, universe):
    """ 
    Given a stream of twits and a universe of tickers, return sentiment scores for tickers in the universe.
    """
    for twit in stream:

        # Get the message text
        text = twit['message_body']
        symbols = re.findall('\$[A-Z]{2,4}', text)
        score = predict(text, model, vocab)

        for symbol in symbols:
            if symbol in universe:
                yield {'symbol': symbol, 'score': score, 'timestamp': twit['timestamp']}

# %%
universe = {'$BBRY', '$AAPL', '$AMZN', '$BABA', '$YHOO', '$LQMT', '$FB', '$GOOG', '$BBBY', '$JNUG', '$SBUX', '$MU'}
score_stream = score_twits(twit_stream(), model, vocab, universe)

next(score_stream)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:90: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# {'symbol': '$AAPL',
#  'score': tensor([[ 0.0683,  0.0056,  0.0223,  0.0359,  0.8679]]),
#  'timestamp': '2018-11-01T00:00:18Z'}

# %% [markdown]
# That's it. You have successfully built a model for sentiment analysis!

# %% [markdown]
# ## Submission
# Now that you're done with the project, it's time to submit it. Click the submit button in the bottom right. One of our reviewers will give you feedback on your project with a pass or not passed grade. You can continue to the next section while you wait for feedback.
